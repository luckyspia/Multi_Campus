# %%
import re
import os
import glob
import pandas as pd
import numpy as np

# %%
path = os.getcwd() + '/data/'
files = glob.glob(path + "/*.csv")

for file in files:
    reg_name = file.split('\\')[-1].split('.')[0]
    globals()['{}'.format(reg_name)] = pd.read_csv(file)

# %%
Yeosu
# Out:
#                                                     제목  \
# 0                                                무난합니다
# 1                                           외관에 돌고래있어요
# 2                                             물고기들 많아요
# 3                                                 좋았어요
# 4    그냥 갈 곳이라고는 거기뿐인 엑스포 장소,,,, 예정에 엑스포할때 저는 전시참가자 ...
# ..                                                 ...
# 851                                            꽤 좋은 :)
# 852                             좋은 곳으로 산책하기에 따뜻한 화창한 날
# 853                                              이 빠진다
# 854                                    거북이가 알을 배는 이 광장
# 855                                  보트 순물질, 하지만 많은 다른
#
#                                                     내용              날짜  \
# 0    가격은 조금 있으나 할인 이벤트가 많으니 자세히 찾아보면 할인을 많이 받을 수 있습...   2021년 5월 • 가족
# 1    외관이 큰게 아주 멋있어요\n여수는 뚜벅이여행도 즐겁구요\n\n경비만 절약해서 유월...  2020년 12월 • 개인
# 2    여수엑스포할때 방문하고 이번에 다시 방문했는데요 여수엑스포때 반문하신분들은 굳이 다...   2020년 7월 • 개인
# ...

# %%
re.sub('[^ㄱ-ㅎ가-힣]',' ',Yeosu['내용'][0])
# Out:
# '가격은 조금 있으나 할인 이벤트가 많으니 자세히 찾아보면 할인을 많이 받을 수 있습니다  작으나 알차게 구성을 해놓았습니다 '

# %%
Yeosu.평점.str[-3:]
# Out:
# 0      4.0
# 1      5.0
# 2      4.0
# 3      5.0
# 4      1.0
#       ...
# 851    4.0
# 852    4.0
# 853    2.0
# 854    4.0
# 855    3.0
# Name: 평점, Length: 856, dtype: object

# %%
Yeosu.날짜[0].split('월')[0] + '월'
# Out:
# '2021년 5월'

# %%
data = pd.read_excel('../../2020년_국민여행조사_국내여행.xlsx')
data.head()
# Out:
#                ID  SA1_1  SA1_2  SA1_3  SA1_4  SA1_5  SA1_6 D_TRA1_CHECK  \
# 0   11010530201_1      0      0      0      0      0      0          NaN
# 1  11010530201_10      0      0      0      0      0      0          NaN
# 2  11010530201_17      0      1      0      0      0      0            Y
# 3   11010530201_2      0      0      1      0      0      0          NaN
# 4  11010530201_22      0      0      0      0      0      0          NaN
#
#    D_TRA1_CASE  D_TRA1_SYEAR  ...  국내_여행방문지_기타당일1  국내_여행방문지_기타당일2  \
# 0          NaN           NaN  ...             NaN             NaN
# 1          NaN           NaN  ...             NaN             NaN
# 2          2.0        2020.0  ...             NaN             NaN
# 3          3.0        2020.0  ...             NaN             NaN
# 4          NaN           NaN  ...             NaN             NaN
#
#    국내_여행방문지_기타당일3  국내_여행방문지_기타당일4  국내_여행방문지_기타당일5  국내_여행방문지_기타당일6  \
# ...

# %%
data.shape
# Out:
# (50710, 2107)

# %%
data.columns
# Out:
# Index(['ID', 'SA1_1', 'SA1_2', 'SA1_3', 'SA1_4', 'SA1_5', 'SA1_6',
#        'D_TRA1_CHECK', 'D_TRA1_CASE', 'D_TRA1_SYEAR',
#        ...
#        '국내_여행방문지_기타당일1', '국내_여행방문지_기타당일2', '국내_여행방문지_기타당일3', '국내_여행방문지_기타당일4',
#        '국내_여행방문지_기타당일5', '국내_여행방문지_기타당일6', '국내_여행방문지_기타당일7', '국내_여행방문지_기타당일8',
#        '국내_여행방문지_기타당일9', '국내_여행방문지_기타당일10'],
#       dtype='object', length=2107)

# %%
# ID별 방문지역, 지출비용, 방문목적, 방문시기
cols = ['ID','SA1_1','SA1_2','SA1_3','SA1_4','SA1_5','SA1_6']

# %%
data.head(20)
# Out:
#                    ID  SA1_1  SA1_2  SA1_3  SA1_4  SA1_5  SA1_6 D_TRA1_CHECK  \
# 0       11010530201_1      0      0      0      0      0      0          NaN
# 1      11010530201_10      0      0      0      0      0      0          NaN
# 2      11010530201_17      0      1      0      0      0      0            Y
# 3       11010530201_2      0      0      1      0      0      0          NaN
# 4      11010530201_22      0      0      0      0      0      0          NaN
# 5       11010530201_3      0      0      1      0      0      1          NaN
# 6      11010530201_35      0      0      1      0      0      0          NaN
# 7      11010530201_55      0      0      0      0      0      0          NaN
# 8       11010530201_8      0      0      1      0      0      0          NaN
# 9       11010530201_9      1      0      0      0      0      0            Y
# 10  11010560051_29800      1      0      0      0      0      0            Y
# ...

# %%
data.iloc[11,110:120]
# Out:
# D_TRA2_CHECK         NaN
# D_TRA2_CASE          5.0
# D_TRA2_SYEAR      2020.0
# D_TRA2_SMONTH        2.0
# D_TRA2_SDAY         19.0
# D_TRA2_EYEAR      2020.0
# D_TRA2_EMONTH        2.0
# D_TRA2_EDAY         19.0
# D_TRA2_S_Day         0.0
# D_TRA2_COST      50000.0
# Name: 11, dtype: object
