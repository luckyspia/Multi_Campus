# %% [markdown]
# ## 네이버 영화평 감성 분석

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
train_df = pd.read_csv('https://raw.githubusercontent.com/e9t/nsmc/master/ratings_train.txt', sep='\t')
test_df = pd.read_csv('https://raw.githubusercontent.com/e9t/nsmc/master/ratings_test.txt', sep='\t')

# %%
print(train_df.shape, test_df.shape)
train_df.head(3)
# Out:
# (150000, 3) (50000, 3)
#          id                           document  label
# 0   9976970                아 더빙.. 진짜 짜증나네요 목소리      0
# 1   3819312  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1
# 2  10265843                  너무재밓었다그래서보는것을추천한다      0

# %% [markdown]
# ### 1. Data Preprocessing

# %%
# Null 데이터가 있는지 확인
train_df.isna().sum()
# Out:
# id          0
# document    5
# label       0
# dtype: int64

# %%
# Null 데이터 제거
train_df.dropna(how='any', inplace=True) 
train_df.shape
# Out:
# (149995, 3)

# %%
# 중복여부 확인
train_df.document.nunique()
# Out:
# 146182

# %%
# 중복 데이터 제거
train_df.drop_duplicates(subset=['document'], inplace=True) 
train_df.shape
# Out:
# (146182, 3)

# %%
# 긍정(1)/부정(0) 분포
train_df.label.value_counts()
# Out:
# 0    73342
# 1    72840
# Name: label, dtype: int64

# %% [markdown]
# - Test data set

# %%
print(test_df.isna().sum())
test_df.dropna(how='any', inplace=True)
print(test_df.document.nunique())
test_df.drop_duplicates(subset=['document'], inplace=True)
print(test_df.shape)
test_df.label.value_counts()
# Out:
# id          0
# document    3
# label       0
# dtype: int64
# 49157
# (49157, 3)
# 1    24711
# 0    24446
# Name: label, dtype: int64

# %% [markdown]
# ### 2. Text Preprocess

# %%
# 한글 이외의 문자는 공백으로 처리하고 strip
train_df.document = train_df.document.str.replace('[^ㄱ-ㅎㅏ-ㅣ가-힣]',' ').str.strip()
train_df.head(3)
# Out:
#          id                           document  label
# 0   9976970                아 더빙   진짜 짜증나네요 목소리      0
# 1   3819312  흠   포스터보고 초딩영화줄    오버연기조차 가볍지 않구나      1
# 2  10265843                  너무재밓었다그래서보는것을추천한다      0

# %%
# '' 만 남은 데이터 --> np.nan 으로 대체한 후 제거
train_df.document.replace('', np.nan, inplace=True)
train_df.document.isna().sum()
# Out:
# 789

# %%
train_df.dropna(how='any', inplace=True)
train_df.shape
# Out:
# (145393, 3)

# %%
# Test data set
test_df.document = test_df.document.str.replace('[^ㄱ-ㅎㅏ-ㅣ가-힣]',' ').str.strip()
test_df.document.replace('', np.nan, inplace=True)
test_df.dropna(how='any', inplace=True)
test_df.shape
# Out:
# (48852, 3)

# %%
# Save
train_df.to_csv('./data/Naver_movie_train_preprocessed.tsv', sep='\t', index=False)
test_df.to_csv('./data/Naver_movie_test_prerocessed.tsv', sep='\t', index=False)

# %% [markdown]
# ### 3. Korean Preprocess

# %%
from konlpy.tag import Okt
okt = Okt()

# %%
text = '교도소 이야기구먼 솔직히 재미는 없다평점 조정'
okt.morphs(text)
# Out:
# ['교도소', '이야기', '구먼', '솔직히', '재미', '는', '없다', '평점', '조정']

# %%
okt.morphs(text, stem=True)
# Out:
# ['교도소', '이야기', '구먼', '솔직하다', '재미', '는', '없다', '평점', '조정']

# %%
stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','도','를','으로','자','에','와','한','하다','을','ㅋㅋ','ㅠㅠ','ㅎㅎ']
' '.join([word for word in okt.morphs(text, stem=True) if word not in stopwords])
# Out:
# '교도소 이야기 구먼 솔직하다 재미 없다 평점 조정'

# %%
from tqdm.notebook import tqdm

X_train = []
for sentence in tqdm(train_df.document):
    morphs = okt.morphs(sentence, stem=True)
    tmp_str = ' '.join([word for word in morphs if word not in stopwords])
    X_train.append(tmp_str)
# Out:
#   0%|          | 0/145393 [00:00<?, ?it/s]

# %%
X_test = []
for sentence in tqdm(test_df.document):
    morphs = okt.morphs(sentence, stem=True)
    tmp_str = ' '.join([word for word in morphs if word not in stopwords])
    X_test.append(tmp_str)
# Out:
#   0%|          | 0/48852 [00:00<?, ?it/s]

# %%
y_train = train_df.label.values 
y_test = test_df.label.values

# %%
X_train
# Out:
# ['아 더빙 진짜 짜증나다 목소리',
#  '흠 포스터 보고 초딩 영화 줄 오버 연기 조차 가볍다 않다',
#  '너 무재 밓었 다그 래서 보다 추천 다',
#  '교도소 이야기 구먼 솔직하다 재미 없다 평점 조정',
#  '사이 몬페 그 익살스럽다 연기 돋보이다 영화 스파이더맨 에서 늙다 보이다 커스틴 던스트 너무나도 이쁘다 보이다',
#  '막 걸음 마 떼다 세 부터 초등학교 학년 생인 살다 영화 ㅋㅋㅋ 별 반개 아깝다 움',
#  '원작 긴장감 제대로 살리다',
#  '별 반개 아깝다 욕 나오다 이응경 길용우 연 기 생활 몇 년 인지 정말 발 로 해도 그것 보단 낫다 납치 감금 만 반복 반복 드라마 가족 없다 연기 못 사람 만 모 엿 네',
#  '액션 없다 재미 있다 몇 안되다 영화',
#  '왜케 평점 낮다 꽤 볼 만 데 헐리우드 식 화려하다 너무 길들이다 있다',
#  '인피니트 짱 이다 진짜 짱 이다',
#  '볼때 마다 눈물나다 죽다 년대 향수 자극 허진호 감성 절제 멜로 달인 이다',
#  '울면 서 손 고 횡단보도 건너다 때 뛰다 치다 올 뻔 이범수 연기 드럽다 못',
#  '담백하다 깔끔하다 좋다 신 문 기 사 로만 보다 보다 자꾸 잊어버리다 그 사람 이다 것',
#  '취향 존중 다지 만 진짜 내생 극장 에서 보다 영화 중 가장 노잼 노 감동 임 스토리 어거지 고 감동 어거지',
#  'ㄱ 냥 매번 긴장 되다 재밋음',
#  '차다 사람 웃기다 바스코 이기 면 락스 코 라고 끄다 바비 이기 면 아이돌 이라고 깔다 그냥 끄다 안달 난 것 처럼 보이다',
#  '굿바이 레닌 표절 인 것 이해 왜 뒤 로 갈수록 재미 없어지다',
#  '이건 정말 깨알 캐스팅 질퍽 하 지 않다 산뜻하다 내 용구성 자다 버무러진 깨알 일드',
#  '약탈 위 변명 이르다 저 놈 착하다 놈 절대 아니다 걸 요',
#  '나름 심오하다 뜻 있다 듯 그냥 학생 선생 놀다 영화 절대 아니다',
#  '보다 웃다 않다 건 불가능하다',
#  '재미없다 지루하다 같다 음식 영화 인데 바베트 만찬 하고 넘다 차이나다 바베트 만찬 이야기 있다 음식 보다 재미 있다 이건 볼 게 없다 음식 별로 안 나오다 핀란드 풍경 이라도 구 경 할랫 늘다 그것 별로 안 나오다 ㅡㅡ',
#  '절대 평범하다 영화 아니다 수작 이라 는걸 말씀드리다',
#  '주제 좋다 중반 부터 지루하다',
#  '다 짤랐을꺼 야 그래서 납득 수 없다 그렇다 꼭 그렇다 끄다',
#  '고추 털다 버리다',
#  '카밀라 벨 발연기',
#  '재밋는뎅',
#  '센스 있다 연출 력 탁월하다 캐스팅 년대 향수 그래서 점',
#  '엄포스 위력 다시 한번 깨닫다 해주다 적 남 꽃 검사 님 연기 정말 좋다 완전 명품 드라마',
#  '졸 쓰레기 진부하다 도안 돼다 아 시간 아깝다',
#  '재밌다 별 점 왜 이리 낮다',
#  '라도 기대하다 내 죄인 이다 죄인 이다',
#  '아직도 드라마 내 인생 최고',
#  '패션 대한 열정 안나 윈 투어',
#  '키이라 나이틀리 연기 대체 정신장애 이다 틱장애 이다',
#  '허허 원작 정신 나가다 유령 이라 재미있다',
#  '포스터 있다 보이다 관객 명 이네',
#  '영화 왜 이렇게 저 평가 받다 모르다',
#  '단순하다 은은하다 매력 영화',
#  '다 알바생 인가 내용 없다 무섭다 없다 웃기다 하나 없다 완전 별 싱겁다 영화 ㅇ ㅇ 내 ㅇ 시간 넘다 아깝다 움 완전 낚임',
#  '오다 두다 서리 굶주리다',
#  '정말 맘 들다 그래서 또 보다 또 보다 방법 없다 ㅜㅡ',
#  '윤제문 이라는 멋지다 배우 발견 돼다 소소하다 일 탈 잔잔하다 미소 머금 게 음악 조금 아쉽다 점 주다 싶다 평점 올리다 싶다 점 주다',
#  '평점 속지 말다 시간 낭비 돈 낭비 임',
#  '리얼리티 뛰어나다 한데 크다 공감 안 간다 이민기 캐릭터 정신의학 상 분노조절 장애 초기 증상 이다 툭하면 사람 패 고 욕 하고 물건 파손 하고 조금 오 바 이다 극 초반 엔 신선하다 가면 갈수록 이민기 정신 상태 공감 불가',
#  '마이너스 왜 없다 ㅋ 뮤비 보고 영화 수준 딱 알 만 ㅉㅉ 북한 에서 이렇다 만들다 돈 대다',
#  '난 우리 영화 사랑',
#  '데 너 리스 타르 가르다 나다 용의 주인 되다 싶다 누 이랑 근친상간 이나 다니다 소설 속 에선 제일 멋지다 놈 메 라 니스 터 이다 드라마 속 에선 드래곤 용 제일 멋지다 웃음 감독 님 토르 다크 월드 말 아 잡수다 기본 선방',
#  '영화 사람 영혼 어루만지다 줄 수도 있다 거치다 세 상사 잠시 잊다 동화 같다 영화 행복하다',
#  '야 세르게이 작다 고추 맵다 맛 보여주다 포퐁 저그 콩 진호 간다',
#  '이렇게 가슴 시리 게 보다 드라마 또 있다 감동 그 자체',
#  '난또 저 꼬마 애가 무슨 원한 깊다 그냥 혼자 나대다 걸 어쩌라고',
#  '재미있다',
#  '전 좋다',
#  '최고',
#  '너무 충격 적다 기분 완전하다 푹 꺼지다 느낌 활 력 이라고는 하나 없다 너무나도 무겁다 지독하다 차갑다 무자비하다 그저 일본인 상상력 정말 대단하다 같다 생각 들다',
#  '심심하다 영화',
#  '백봉기 언제 나오다',
#  '보다 그대로 들어맞다 예측 카리스마 없다 악역',
#  '불알 나오다 당황 아무튼 영화 중간 끝나다 느낌',
#  '평범하다 속 녹다 평범하다 일상 조금 밋밋하다 흠',
#  '보다 계속 보다 전개도 느리다 주인공 인 은희 한두 컷 나오다 소 극적 인 모습 짜증 ㅜㅜ 맨날 언제 끝나다 기 대만 하고 있다 전개 빨리 빨리 ㅜㅜ',
#  '사랑 하고 싶다 가슴속 온 감정 헤집다 영화 예요 정말 최고',
#  '많다 사람 다큐 보고 우리나라 슬프다 현대 사의 단면 대해 깊이 생각 하고 사죄 하고 바로 잡기 위해 노력 말로 만 듣다 보도 연맹 그 민간인 학살 이정 일 줄 이야 이건 명백하다 살인 이다 살인자 다 어디 있다',
#  '예전 작품 캐릭터 에피소드 재탕 삼 탕 사골 우려 먹듯 우리 고 내용 산 가다 시청률 아예 안 나오다 이제 회 중반 인데 부작 이라니',
#  '김남길 백 점 짜다 연기력 초반 몰입도 에도 불구 하고 지루하다 손예진 ㅈㅈ',
#  '재밌다 비슷하다 영화 안 보다 분 한테 늘다 재미있다 듯',
#  '노래실력 뽑다 맞다 박시환 나가다 진짜 망신 이다',
#  '아 일본 영화 다 이런 건가 유치하다',
#  '이틀 만에 다 보다 재밌다 근데 차 안 물건 넣다 조작 차 안이 열리다 집 안이 활짝 열리다 아무나 들어가다 문자 조작 비번 안 걸리다 ㅋㅋㅋ 그렇다 건 억지스럽다 그래도 내용 자체 좋다',
#  '졸작',
#  '재밋네 요 달팽이 빨 라서 더 재밌다',
#  '어설프다 전개 어이없다 결말',
#  '부패하다 로마노프 왕조 기리 뭣같 영화 온몸 항거 러시아 민중 그저 폭도 냐',
#  '내용 전개 무난 펴다 자다 보다',
#  '매우 실망',
#  '한국영 화 흥행 코드 갈등 갈등 계 속 갈등 화해 감동 평점 점 남발 흥행 뻔하다 뭐',
#  '아햏햏 아햏햏 아햏햏',
#  '뭐 냐 시작 하고 분만 나오다 리플릿 사진 보다 불안하다',
#  '단연 최고 라고',
#  '감독 럼 먹다 영화 만들다 관객 에게 뭘 말 모르다 엉망 진창 개 진창 이다',
#  '이건 뭐 냐 우뢰매 냐',
#  '정말 쓰레기 영화 이다',
#  '진정 위대하다 영화 최고 임',
#  '별루 이다',
#  '내일 기대 되다',
#  '근데 조미 막문위 좋아하다 가요',
#  'ㅋㅋㅋ 진짜 골깜 눈 부라리다 때 쓰러지다',
#  '성룡 영화 중 최악 인 듯',
#  '골 때리다 ㅋㅋㅋㅋ 걸스데이 이혜리 자다 되다',
#  '서기 이쁘다',
#  '완전 재밌다 ㅋㅋㅋㅋㅋ 백 인공 주귀 여 움 ㅋㅋㅋㅋㅋㅋ',
#  '인상 적 인 영화 이다',
#  '어내스트 셀레스틴 완전 강추 에요 정말 재밌다',
#  '재미있다 영화 이다',
#  '클라라 볼라 고 화신 보다 아니다',
#  '진짜 보다 너무 슬프다 영화 다',
#  '설정 재밌다 새롭다 에피소드 내 에서 메인 스토리 차차 나오다 재밌다',
#  '신카이 마코토 작화 밉다 유 하나 카나 연기 해주다 더 대박 이다',
#  '재미없다 진심 이훨 나 캐스팅 두 못 듯',
#  '잔잔하다 생각 보다 볼 만 영화 인거 같다 ㅋ',
#  '감독 님 들다 고은님 쓰다 영화 안 보다',
#  '무섭다 않다 스토리 ㅡㅡ',
#  '영화 속 억지스럽다 노골 적 인 술 광고 은은하다 센스 있다 어떻다',
#  '킬링타임',
#  '크리스마스 떠오르다 영화',
#  '재미있다 보다 매력 적 인 행복 이네 요 ㅎㅎㅎ',
#  '음악 완전하다 빠지다 볼 수 있다 영화 쫌 산만하다',
#  '태어나다 처음 영화 보다 중간 나오다 불륜 로맨스 냐',
#  '왕 짜증 아주 전개 짬뽕 믹스 음향 만 무섭다 하아',
#  '솔직하다 난 별루더 라 시간 낭비 느낌',
#  '대박',
#  '시청률 기준 되다 패널 가구 머 명작 드라마 다 망치 네 ㅡㅡ 내 다 서운하다',
#  '내용 이상하다',
#  '몬스터 주식회사 재밌다 보다',
#  '내용 전개 너무나 느리다',
#  '소재 흥미 끌 지만 이야기 전개 투 박하다 몰입 안되다',
#  '절대 보다 쓰레기 영화',
#  '중국인 특유 과장 허풍 있다 보이다 안간힘 쓸다 노력 가상하다 고증 현 실감 떨어지다 설정 거북 스럽다 도대체 그 왜 이렇게 까지 스스로 과대 포장 하 것 인지',
#  '그냥 불법체류자 때리다 잡다 영화 면 좋다 무슨 우상화 만들다 미국 따뜻하다 설정 이건 뭥미',
#  '년 삶속 주인공 생애 전부 드러나다 듯',
#  '별 점 점 가다',
#  '별로 다',
#  '보다 꽤 지난 후 남다 재미있다',
#  '아니다 게 왜 점 대 이다',
#  '년 지나 다시 보다 되다 영화 다시 보다 그 순수하다 사랑 감동 숀펜 연기 또한',
#  '올레 공짜 로 있다 보다 헐다 스토리 문제 아니다 연기자 전혀 배역 이랑 어울리다 않다 그리고 상대 배우 하고 다 따로 놓다 같다 이건 연기자 문제 있다 보아 진심 완전 별로 임 라미란 하고 아들 젤 볼 만',
#  '너무 욕심 많다 영화 어느 쪽 만이라도 제대로 보여주다',
#  '아 빵점',
#  '베댓 말 아주 잘쓰다',
#  '아주 모자라다 않다',
#  '영화 도둑 이나 뫼비우스 같다 나라 에서 만들어지다 믿어지다',
#  '온몸 찌릿 짜릿 나 두 용기 가다',
#  '정말 재미있다 교훈 적 인 영 화이 네 요',
#  '당시 상황 주제 주입 식이 아니다 긴장감 있다 재밌다 전하 작품',
#  '케이블 에서 그만 나오다 주다',
#  '다르덴 이다 투 차이밍량 하나 안 섞이다 채 짬뽕 그릇 담기다',
#  '여군 잼 없다 뭐 건지다 ㅡㅡ 잼 없다 엠비씨 다 잼 없다 질린다 이제',
#  '좋다',
#  '한석규 김혜수 연기 만 돋보이다 영화 어딘 지 모르다 많이 어설프다 영화',
#  '솔직하다 에볼라 바이러스 떠들다 석 해 서 보다 되다 영화 인데 작품 성 이나 어떤 면 에서도 여 년전 영화 라고 보기 엔 믿다 힘들다 정도 로 정말 만들다 보다 마지막 후반 부가 살짝 아쉽다 하지만 정도 면 수작 이라고 보다 시간 아깝다 않다 영화',
#  '볼 만해',
#  '재미있다 허풍 떨다 말다',
#  '용가리 진짜 짱짱맨 이다 ㅋ',
#  '영화 이제 서다 보다 감히 내 인생 최고 영화 중 하나로 꼽 수 있다 작품 어떻다 살 아 야하다 나르다 위 고민 한번 더 되다 시간 그리고 모건 프리 멀다 나이 들다 여전하다 섹시하다',
#  '작가 별로 다 내 용이 진짜 별로 임 맨날 그냥 기대 하고 재방송 혹 시나 하고 보다 답 없다 진짜',
#  '명작 이렇다 명작 있다 싶다 보고 또 보다 여운 남다 영화',
#  '아 진짜 조금 만 더 손 보다 왠만하다 상업 영화 못 지 않다 퀄리티 쩔다 만들다 질 수 있다 아쉽다 그래도 충분하다 재미있다 개인 적 조금 만 더 잔인하다 더 자극 적 노출씬 화끈하다 어떻다 국산 영화 라 많이 아끼다 듯 보임',
#  '그만 끌 고 이제 끝내 라 지겹다 지겹다',
#  '아',
#  '역시 드니 로 연기 일품 나다 맥스 샘 죽이다 바랬다',
#  '나름 괜찮다 작품 이다',
#  '너무 좋다 영화',
#  '정말 실망 스러웟음',
#  '배우 지네 안 뜨다 이런 영화 찍을껀데 왜 안 뜨다 진짜 모르다 면상 딱 보다 알다 왜 지네 자신 모르다',
#  '어린이 좋아하다 내 어리다 적 동심 멀리 뜨다 낫다',
#  '무술 인 왜 총을드 나',
#  '점',
#  '크리스토퍼 왈츠 타란티노 조합 이란',
#  '한국 에선 유명 한편 아니다 외국 에선 상상 초월 유명하다 영화 이다',
#  '오랜 만 재밋 늘다 영화 보다',
#  '종방 되어다 아쉽다 오늘 막 방도 보다 방송 대본 꽤 완성 있다 느낌 받다 요즘 드라마 막장 지치다 수백향 정말 바른 드라마 이다 해 요 악역 그리다 심하다 어이없다 않다 화이팅',
#  '평점 조절 위원회 에서 나오다 웃음 김혜선 내일 오다 김 순정 순정 역할 제일 이다 팜므파탈 로써 그 정도 까지 해내다 줄 정말 의외 이다 연기 년 사람 에게 요즘 사극 에서 벌어지다 있다 그녀 대한 연 기 논란 왠지 코미디 장면 같다 웃음',
#  '영화 끝 나가다 때 쯤 멍하다 다 보다 한마디 나오다 임 ㅈ 같다',
#  '공유 존잘 ㅎㅎㅎ',
#  '상쾌 발랄하다 영화 다 말 껄끄런 성 이란 소재 유쾌하다 해설',
#  '소파 죽 치고 앉다 지키다 볼 이유 없다 작품',
#  '로큰롤',
#  '주된 타겟 어린이 니 일반 적 인 논리 통 않다 건 알다 하지만 게임 흥미롭다 않다 요원 이라는 주인공 너무 무능력하다 별로 재미없다 배경 거슬리다',
#  '뮤지컬 영화 인데 사운드 녹음 엉망 남다 춤 못 추다 내용 뻔하다 뻔 주인공 목소리 너무 안 어울리다 어제 에서 뛰다 나가다 참다 진심 말리 고 싶다 영국 저 예산 용 영화 뮤지컬영화 아니다 맘마미아 안되다',
#  '어리다 보다 꽤 나 좋아하다 로맨틱코미디',
#  '게이물 인 줄 모르다 보다',
#  '알바 끄다 저 라',
#  '영화 머임 내 왜 받다 보다 그것 알고싶다 영화 배우 스텝 감독 꼭두각시 이다',
#  '대다 라니 최악',
#  '정말 아름답다 영화 이다',
#  '자극 적 인 것 익숙해지다 현대인 보다 눈 떼다 힘드다 연출 력',
#  '뻑 뻑 자다 읽다 볼걸 나다 당하다',
#  '정말 짜증 극치 보여주다 영화 굉장하다 언밸러스 느낌 뚱뚱하다 못 생기다 남자 애 발연기 시종일관 보다 고역 인 듯 간간히 흘러나오다 잔잔하다 클래식 풍 음악 조차도 듣기 싫다 짜증나다 정도 로 상당하다 싫다 영화',
#  '감동 감동 ㅜㅜ 정말 최고 네 요',
#  '별 점 주기도 아깝다 얼마나 내용 진부하다 욕 밖에 안 나오다 보고 재밌다 사람 초딩 인가요 죄송하다 너무 화가 나서다 아무 것 볼 게 없다 보지 말다 그냥 티비 판 짜지다 거 같다',
#  '나 왠만하다 짜증 알다',
#  '돼지 피 먹다 닭목 따다 장면 에선 우웩 역시 무당 아무나 아니다',
#  '버리다',
#  '유치하다 지루하다 잠 오다',
#  '류 풍 판타지 점 만 가져가다',
#  '윤종신 복귀 좋다 이하늘 도대체 왜 뽑히다 알다 없다 참가자 실력 따다 전 심사 위원 인격 실력 부터 쌓다 오다 어 하 어허 그만',
#  '광장 작품 옛날 것 보고 싶다',
#  '내 생 최고 영화',
#  '어린시절 너무 무섭다 재미있다 보다 추억 판타지영화 절대 나쁘다 짓다 금물 지옥 가요',
#  '기존 멜로영화 형식 탈피 감정 절제 지나치다 너무 담백하다 영화',
#  '난 사랑비 서준 에게 쏙 빠지다 버리다 초 만에 쏙 난 절대 잊다 않다 후회 도안',
#  '이영화 보 니까 교훈 주네 요 나다 남다 인생 화려하다 살다 말 밖에 안 나오다',
#  '나름 추억 젖다 들다 좋다 아무 생각 없이 가볍다 보고오다 추천 요',
#  '단순하다 싸이코 물 벗어나다',
#  '게 년도 만들어지다 가요 아니다 예전 만들다 다시 개봉 건가 요 ㅠ 너무 허다 접해 요 ㅠ',
#  '넘다 사랑스럽다 영화 다 보고 연 어 보다 넘다 귀엽다',
#  '청춘 영화 만이 줄 수 있다 감성 넘치다 나다 순간 지나가다 다시 돌아오다 않다 그 순간 만큼은 무한 젊음 줄 수 있다 그렇다 감성',
#  '용 건담 시리즈 중 에서 아직 까지도 최고봉',
#  '개콘 요즘 갈수록 코너 다 노잼 이고 웃음 이안 난 다',
#  '사다코 서린 우물 펀치 ㅜㅜ 감동',
#  '후세 사랑 되다 결정 적 계기 그 시간 표현 되다 않다 시 람 생명 빼앗다 이유 등 시 노 출현 연극 으 로 더 알다 생각 이든 다 또한 시 노 얼마나 본능 절제 히 면서 시 랑 노력 더 보여주다 좋다 뻔하다',
#  '새벽 시간 일본 영화 전부 개 졸작 이다 일 본 영화 원 래 다 이래',
#  '강수연 나가다 그리고 최정원 신음 신',
#  '아 정말 김혜성 너무 예쁘다 이현진 웃다 거 정말 하',
#  '가발 쓰다 싶다',
#  '화려하다 여정 이인상 깊다 재밋어 요 배두나 연 기 정말 ㅋ',
#  '대들다 위 성적 호기심 영화',
#  '감동 적 인 영화',
#  '이건 말 필요 없다 그냥 닥치고 보다',
#  '각기 다른 사람 재밌다 멋지다 사랑 영화',
#  '역시 미국드라마 파워 정말 알다 없다 그 미묘하다 사로자다 버리다 최고',
#  '너무 너무 훈훈하다',
#  '거 응답 하라 에서 은지원 원 스스로 욕 않다 ㅋㅋㅋㅋ',
#  '아 너무 웃기 고 배꼽 빠지다 뻔하다 내 컴 영화 있다',
#  '구성 상당하다 부실하다 영화 역시 네이버 평점 믿다 없다',
#  '장끌 로드 몰락 가져오다 오우삼 헐리우드 작품 중 가장 재미없다 졸작',
#  '언 제적 영웅본색 연출 인지 현실 성 제로 인 영화',
#  '작다 하나 에도 설레다 학창시절 그때 그 느낌 다시 느끼다 보다 시간 이다 장면 하나 하나 대사 하나 하나 배경음악 하나 하나 버리다 없다 드라마',
#  '진심 재미 없다 너무 평점 높다 화남',
#  '더럽다 재미없다 어떻다 형태 로 오다 닿다 않다 허무하다 완벽하다 지루하다 영화 고 영양가 하나 없다 영화 다',
#  '이승기 정말 연기 조연 연기 정말',
#  '현실 꿈 꿈 현실',
#  '오늘 현충일 특집 프로 로 보다 되어다 년도 매우 훌륭하다 작품 이다',
#  '판 미로 동 급',
#  '제대 하고 보 니까 더 재밌다 ㅋㅋㅋㅋ',
#  '영화 보다 마음 휴가 다녀오다 느낌 소박하다 잔잔하다 지루하다 않다 그래서 다시 보다 영화 햇살 가득하다 비 이의 부엌 요리 인상 적',
#  '코믹 건 좋다 짜임새 너무 허다 술 하 다',
#  '년 그때 당시 에는 우리 나라 이렇다 판타지 로맨스 없다 아직도 신현준 황 장군 연기 음 괜찮다 한석규 전 성 시 대가 열리다 영화 때 한석규 한테 뿅 가다',
#  '일단 재생 괴물 같다 서스펜스 귀신 같다 흡입 력',
#  '하 진짜 댓글 보고 한번 쯤 볼 만 영화 인거 같다 보다 기 차다 게 무슨 버킷리스트 인가 죽다 직전 소원 들어주다 내 가보다 죽다 직전 막 살다 이다 같다 감동 없다 진짜 버킷리스트 란 영화 발톱 때 만큼도 못 따라가다 쓰레기 영화 완존 실망',
#  '시간 밝다 긍정 적 인 드라마 보다 보다 보다 오버 연기 거슬리다 연기 인게 너 무표 나 요 홍혜정 역 이그 나 마도 후련 기도 하고 시원하다 나머 지다 들다 답답하다 낼 월요일 인데 해피 것 만 보고 싶다',
#  '정치인 모순 인가 정치범 모순 인가',
#  '어떻다 이렇다 상상 대단하다',
#  '어렵다 기도 전쟁 대한 묘사 자다 모르다',
#  '일본 에서 주년 극장판 만들다 우리나라 에선 주년 재개 봉하 니 이건 ㅄ 아니다',
#  '대희 개그콘서트 보다 내 전화 끊음 개그콘서트 없애다 ㅡㅡ',
#  '물 간 동 서양 두 배우 싸움판',
#  '푸하하하 거 기대 안 역시 나 구만 ㅋ',
#  '세계 최초 반공 애니매이션 이라는 역사 적 가치 있다',
#  '감각 적 인 시각 바라보다 색다르다 느낌 사랑 문학 적',
#  '엄마 무고 지다 딸 감옥살이 시키다 시키다 이해 안 돼다',
#  '이영화 제발 책 보다 감독 미치다 겁니다 이따위 로 만들다 화가 날 정도 ㅡㅡ',
#  '신나다 흑인음악 아이스 큐브 뿐 남다 없다',
#  '드럽다 재미없다 시간 돈 이다 내 시간 어쩔 건데',
#  '그저 한마디 뿐 알리시아',
#  '진짜 생생하다 느끼다 수 있다',
#  '재밌다 평점 이상하다 싶다 정도 로 낮다',
#  '옥소리 프로필 사진 점 남다 가다 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 완전 대박 이다 진짜 아우 짜증나다',
#  '드라마 너무 재밓당',
#  '아 진짜 너무 좋다 ㅜㅜ 짱짱',
#  '연기 굿',
#  '이렇다 영화 다시다 안 나오다 그때 시절 나타내다 같다',
#  '중간 정도 부터 보다 꽤 나 대단하다',
#  '콩 끄다 제 맛 콩 끄다 제 맛',
#  '이적 소설 재미없다',
#  '액션영화 아니다 범죄 느와르 영화 다 허다 범죄 느와르 영화롭다 실패 작',
#  '뭔가 알다 없다 매력 빠져들다 영화',
#  '모녀 토막 살해 살인자 부 성 애 라니 말 되다 감동 받다 사람 본인 피해자 되다 감동 받다 진심 묻다',
#  '재밌다 평점 왜 이렇게 구리지',
#  '아 기 걸 보다 내 눈 아깝다 ㅡㅡ 진짜 아 놓다 진짜 기 명작 이네 요',
#  '필름 값 아깝다 재미 더럽다 없다 점 부터 점 수준 것 매미',
#  '또 보고 싶다 어디서 보다',
#  '영화 재미있다 드 만',
#  '남 주인공 연기력 안습 이네 요 혀 짧다 소리 듣기 너무 힘들다 매니저 역활 분 남 주인공 훨 좋다 생각 들다 정도 영화 자체 적당하다 볼 만',
#  '점 딱 액션 스릴러 인데 액션 스릴 없다',
#  '완전 스토리 엉망 이구 완전 비추다 ㅜ',
#  '영화 뭘 전달 모르다 오글거리다',
#  '좋다 영화',
#  '더빙 이상하다 할머니 월 래 익숙하다 ㄷㅔ',
#  '게 편이 나오다',
#  '모든 게 씩 다 부족하다 아니다 씩',
#  '정말 말 그대로 쇼 영화',
#  '년 전 보다 기억 나다 않다 진개 천카이거 감독 이름 세 자다 기억 두다',
#  '정은지 언니 연기 노래 부르다 마지막 회 웃다 즐겁다 보다 트로트 연인',
#  '게 웃기다',
#  '망하다',
#  '아이 시선 보다 전쟁 보다 내내 가슴 먹다 먹다',
#  '사람 재미없다 레알 기대 안 생각 보다 볼 만 함 근데 여자애 랑 복 순이 랑 다투다 장면 그건 굳이 없다 돼다 생각 함 몰입도 겁나다 없애다 어색 해보다',
#  '설정 연속극 같다 느낌 들다 하지만 배우 연기 뛰어나다',
#  '여 주인공 인터뷰 때 지루하다 죽다 알다 ㅡㅡ 그냥 저 냥 킬링타임 용 스릴러',
#  '전 밉다 박스 오피스 위 그냥 몰다 건가 어떻다 이런 영화 위 옛날 년대 우뢰매 수준 물폭탄 싸움 이네 손 에서 비다 손 에서 물폭탄 나가다 다르다 뭐 지',
#  '감독 여자 다 보다 기량 많이 딸리다',
#  '또 보고 또 울 었 다',
#  '이렇다 영화 하나 개연 성 만 없다 허무하다 만들다 버리다 조디 포스터 이쁘다 모습 만 남 영화',
#  '굳다 굳다',
#  '스토리 말 안되다 개막 장 사랑 이야기 아니다 걸 보고 계시다 당신 시간 돈 아끼다 휴 그래도 보다 호구',
#  '네 놈 살리다 두기 엔 쌀 아깝다 세기 명대사',
#  '평점 너무 높다 전혀 재미있다 않다 쓸데없이 말 만 많다 이렇다 류 영화 조연 뒷받침 중요하다 조연 내용 자체 전혀 없다 또한 여배우 별로 매력 없다 이틀 전 저스트 고 위드 잇다 애니스톤 보고 영화 보다 그 런가 실망하다',
#  '맛깔 나 드라마',
#  '시베리아 인가 거기 가다 훈련 때 나오다 개 작살',
#  '이건 시종일관 질 질왜 제목 야경 꾼 이다 지금 회 넘어가다 즉 달이 넘어가다 앞 에서 누군가 얘기 거 부 작다 그렇다 또 순간 모든 걸 훅 진짜 지루함 지존',
#  '나이 수록 이해 가다 영화',
#  '슬픔',
#  '장면 개연 성도 없다 아역 연기 못 하고 무슨 추노 나오다 민폐 언 년 외국 파다 초반 만 그렇다 싸하다 저급 영화',
#  '영화 정말 별루 예요 결말 이상하다',
#  '딱하다 재미 없다 킁',
#  '송강호 정말 연기 위해 태어나다 그로 인하다 우리 즐거움 느끼다 역시 송강호 연기 파다',
#  '일본 영화 수입 금지 시절 에도 비디오 테이프 로 돌리다 보다 불후 명작 아 그리다',
#  '살인 소재 로 영화 토록 재밌다 줄 이야 살인 대한 감독 해석 정말 재치 있다 대다 배우 님 들다 여 년전 모습 새롭웠 고 ㅋ 정말 유쾌하다 재밌다',
#  '누 밉다 라파스 신봉선 닮다 안 보다',
#  '케이블 에서 그만 재탕하다',
#  '멋지다 정말 이지 멋지다 말 이외 엔 말 없다',
#  '년 어떻다 이런 영화 만들어지다 의문 당대 최고 영화 지금 보다 퀄 에서 결코 떨어지다 않다',
#  '지금 거 티비 로 돈 내다 보다 내 한심하다',
#  '쓰레기 연예인 재기 장 그러나',
#  '굿 좋다',
#  '많다 감동 준 드라마 이다',
#  '발 로만 든 영화 지지다 주인공 넘어지다 뒤 로 사람 유유 히 걸다 있다 발 발연기 발 시나리오 내용 정말 뭐 같다 ㅋㅋㅋ',
#  '적당하다 언제 끝나다',
#  '잊다 수 없다 안개 끼다 워터 루 다리 마스코트',
#  '곤 사토시 감독 년 안타깝다 돌아가다 가슴 먹다 먹다 정말 천재 적 인 감독 인데 암 갈다 이제 서다 다시 보다 모든 작품 대작',
#  '많다 생각 돼다 예 뼈 지고 싶다 맘 있다 독 이겠다',
#  '아 츠무구 만 없어지다 별 개다',
#  '어리다 땐 조폭 영화로 알다 나이 들다 게 인생 이구나 뭉클하다 영화 세상 살아가다 갈수록 오다 닿다 많아지다 세상 비정하다 비정하다 지다 따뜻하다 친구 라고',
#  '영상 너무나도 멋지다',
#  '비디오 있다 보다 년도 인 줄 모르다 정도 로 만들다 긴장감 있다',
#  '처 ㅝ 주',
#  '년 만들어지다 재밌다 영화 기다 다듬다 소재 좋다 몰입 감다 기 대 이상 매끄럽다 못 부분 있다 연기 둘 다',
#  '철 지난 조폭 코미디 뼈대 있다 가문 이야기 섞다 둘 다 지루하다 박정아 비롯 배우 보기 민망하다 연기 펼치다 기억 남다 건 하나 없다',
#  '군더더기 없이 자다 진행 되다 재미 없다 문제',
#  '심심하다 보다 재밌다 탑 연기 못 알다 배우 포스 나다 자다',
#  '고 다미 괜찮다',
#  '아 지대 짜증 아빠 랑 봣는데 민망하다 죽다',
#  '점 못 주다',
#  '빠순이 영화 ㅋㅋㅋㅋㅋㅋㅋ 훈훈하다 긔 재밋쎠',
#  '최악 애니메이션 지루하다 재미없다 스토리 마저 진부하다',
#  '좋다 의도 와는 다르다 불쾌하다 표현 법',
#  '줄리아 로버츠 귀엽다 연인 거 보다 년전 꺼 다',
#  '신선하다',
#  '예술가 로써 사람 인생 당시 시대 적 상황 질 느끼다 수 있다 명작',
#  '관객수 너무 아쉽다 영화 베테 랑 보다도 더 류승완 감독 역작 이고 더 강하다 악역 이다',
#  '한창 핵 펭귄 남북 거짓 평화로 전 국민 속 이던 때 만들어지다 영화',
#  '지금 티비 에서 못 보다',
#  '여자애 명 자다 못 몇 명 죽다 답 없다 ㅋ',
#  '성룡 헐리웃 작 중 단연 최고 지 ㅋㅋㅋ',
#  '안습',
#  '감독 의도 전혀 알아차리다 못',
#  '하나님 가정 오다 만들다 진리 신분 이만 든 영화 눈 으로만 보지 말고 마음 보다',
#  '편도 나름 흥미진진 데 핀 헤드 죽다 아쉽다 점 랄 끄다',
#  '국산 코미디 영화 중 에서 난 신라 달밤 제일 좋다 뭔가 푸근하다 따뜻하다',
#  '최악 이다 영 화보 다가 자다 첨 임 지루하다 둑 뻔',
#  '탄탄하다 배우 되다 머 건지다',
#  '영화 점점 끝 달려가다 몰입도 더 높아지다 영화 이번 처음 이네 요',
#  '결국 감독 자신 싶다 의견 지존파 핑계 삼다 듯 지존파 살인 정당화 하고 정부 탓 이다 사회 탓 이라는',
#  '사실 여부 떠나다 알 고 오다 아더 너무 매칭 안 돼다 원탁 기사 중 실제 검술 최고 수 랜슬롯 알 고 있다 트리스탄 보다 못 하고 싸우다 검술 마치 중국 검술 흉내 내다 같다 그리고 란슬롯 실제 쌍 검다 너무 매칭 안대 하 틀다 ㅋ 기네 비어 역도 미스',
#  '대한민국 영화 수준 평균 치르다 하락 시키다 충분하다 급 영상 물',
#  '점 없다',
#  '재밌다',
#  '재미없다 기대 완전 완전 못 실망',
#  '종착역 없다 인생 대유 트레비스 단지 흘러가다',
#  '돈 시간 아깝다 영화',
#  '네러티브 하나 없다 예쁘다 음악 동영상 취미 로 영화 만들다 것 걸 로 끝나다 음악 올인',
#  '배우 연기 좋다 뭘 말 건지다',
#  '학위 위조 성범죄자 문 제자 만 모으다 영화 찍다 왜 그렇다 제작비 아끼다 구 패자부활전',
#  '솔직하다',
#  '완전 재미있다 애 보기 알맞다',
#  '잔인하다 무섭다 ㅠ 탑 멋있다',
#  '무섭다 않다 기분 만 나쁘다 쩝',
#  '군더더기 없다 깔끔하다 그러나 강하다 메세지 전달 뜻밖 차다 좋다 영화',
#  '영화 최고다 그냥 최고 야 그렇다 줄 알 아',
#  '그랜드 부다페스트 호텔 시리즈 같다 캐스팅 아깝다',
#  '빨리 감기 보다 투자 비다 많이 들다 것 같다 영화사 망하다 ㅎ',
#  '도대체 뭐 재밌다 건지다 모르다 무슨 아이언맨 시리즈 개그 뛰어넘다 어디서 웃다 야하다 모르다 내용 뭔 지 뜬금 없다 히어로 놀이 또 뭔 지 왜 이렇게 평점 높다 모르다',
#  '왜 극 끌다 중심 있다 캐릭터 있다 알 게 되다 영화 살인마 대적 그리고 사건 해결 인물 없다 그리고 왜 마지막 다 탈출 나서다 잡히다 죽이다 당하다 이해 없다 대체 조달환 정유미 왜 나오다',
#  '진 짜다 리얼 개 쓰레기 영화 다 보고 나다 정말 찝찝하다 영화 절대 보다',
#  '비록 로봇 이지만 점차 인간 감정 가지 고 자신 대해 고민 결국 인간 되어다 죽다 앤드류 모습 내 보다 영화 중 에서도 최고 감동 선사 영화',
#  '영구 땡 칠이 시리즈 레전드 영화 다',
#  '초딩 때 친척 형 비디오 로 빌리다 서다 보다 기억 나다 너무 재미 없다 근데 나중 우연히 다시 보다 재밌다 그 땐 왜 그렇게 재미 없다 년 면 내 초등학교 학년 때 니까 사촌형 당시 나름 최신 비디오 빌리다 오다 같다',
#  '지루하다 고요하다 서글프다 시 선속 머물다 깊다 성찰 사색',
#  '영화 진짜 보고 펑펑 울다 너무 슬프다 같다 ㅜㅜㅜ',
#  '누가 더 혀 짧다 내기 박빙 이다 같다',
#  '애 둘 딸리다 심은하 그 눈부시다 미모 아름답다 영상 메인 주제가',
#  '기 나오다 아직 안 풀리다 이야기 많다 극장판 정말 시간 가다 모르다 보다 역시 싸다 패',
#  '개 노잼 뭔가 스토리 부족하다 다 이상하다 진짜',
#  '답 없다 뭐 건지다',
#  '절망 슬픔 속 에서도 자신 챙기다 삶 잔인함 거부 비참하다 대하 여',
#  '페이스 허다 같다 ㅋㅋㅋㅋㅋ',
#  '시간 흐르다 퇴색 되다 않다 맛 있다 영화',
#  '진짜 어마어마하다 여운 주다 멜로 영화 에요 ㅎ',
#  '소 피 마르 소 와의 말 같다 않다 불륜 내용 다 망치다 물론 실제 역사 에는 그렇다 똥 같다 이야기 전혀 없다 주인공 죽 때 공주 살다 한마디 만약 미국인 맞서다 싸우다 아메리칸 원주민 자유 투쟁 기다 절대 아카데미상 못 받다',
#  '훈훈하다 따뜻하다 부정 느끼다 잇다 엇음',
#  '잼',
#  '전 정말 재미있다 보다',
#  '어딘가 에서 일어나고 일 일 것 같다 느낌 강하다 우베 볼 이렇다 영화 만들다 이유 누군가 실제 로 따르다 바라다 같다 정장 월 있다 애 보다 웃다',
#  '림프비즈킷 만 점 개봉 당시 극장 에서 보다 영화 내내 오우삼 쥑 이고 싶다',
#  '견자단 대박 엽문 시리즈 계속 되다',
#  '정말 오월 멜로 정말로 보고 보고 또 보다 계속 보다 영화 순위 순위 다 하 늦다 밤 이라 그렇다 야릇하다 느낌 들다',
#  '흥미롭다 보다 여배우 이쁘다 반하다',
#  '스토리 액션 그래픽 머 하나 건지다 없다 망작 그냥 게임 으로나 즐기다',
#  '그냥 레전드 다 레전드',
#  '평론가 명치 겁나다 때리다 싶다 정말 영화 재미없다 생각 재미 있다 내 인생 도움 가장 크다 영화 이다 본인 깨달 고 싶다 꼭 보다 인생 바꾸다 겁니다',
#  '키 아누 리브 스 최고 액션 영화',
#  '소재 아름답다 영화 다소 아쉽다 부분 있다 이유 영화 영화 스러운 극적 로맨스 보단 더 사실 적 남자 마음 시선 말 하고 싶다 때문 아니다',
#  '영화평론가 아니다 좋다 한번 보고 마는 영화 아니다 울리다 영화',
#  '역시 효느 역시 재밌다 ㅋㅋㅋ 재탕 중',
#  '대강',
#  '간첩 색휘 애쓰다 밥 먹다 다니다',
#  '검증 되다 애 출현 시키다 이탈리아 특집 장난',
#  '아 정말 짜증나다 절때 보다 껄욕 나오다',
#  '슬프다',
#  '최악 환경 속 에서 이렇다 만화 라도 만들다 사람 에게 경의 보내다',
#  '여운 엄청 길다 남다 영화 이이경 사랑 영화',
#  '이딴 게 한국 영화 라니',
#  '짜다 게뭐 여 뭔',
#  '굿 이상 가나다라',
#  '짱 이다 ㅎ 혼자 자식 키우다 살아오다 엄마 그 의아 힘들다 살아오다 서로 예민하다 날카로워지다 때 잇다 엇 지다 결국 가족 ㅎ 아빠 라는 사람 생각 보다 최악 아니다 여자 확실하다 요구 도와주다 그 말 왠지 짠하다 닿다 ㅎ 나 혼자 괜히 끙끙 거리 지 말 ㅡ 이런 단 순 생각 이든 다',
#  '별로 고 전개도 별로 고 연기 별로 고 한마디 로 재미없다',
#  '번 지수 잃다 갈팡질팡',
#  '너무 사랑스럽다 감동 적 인 영화 정말 좋다',
#  '최고 영화',
#  '년전 영활 다시 보다 공효진 코 평수 줄 이고 콧대 높이다 완전 못 생기다 호 권상우 화산고 때 왼쪽 팔자 심하다 지금 사라지다 더 잘생기다 장혁 멋지다 늙다 ㅋㅋㅋ 다시 보다 웃기다',
#  '말랑말랑',
#  '공부 열심히 공부 안 저런 인생 사다',
#  '그냥 최고다',
#  '전쟁 이후 아픔 자다 그린 영화 마지막 장면 압 권 유대인 줄 알 아 더럽다 여기 나 도움 필요하다 동행 토마스 에게 더럽다 유태인 이라고 말 장면 그러나 유대인 인척 사실 유대인 가족사진 보다 미묘하다 감정 사슴 인형 밟다 며 대변 므 찌다 영화',
#  '오랜 만 동화 다운 동화 보다 기분 이다',
#  '감사하다 정말로 감사하다',
#  '두다 변태',
#  '샤넬 인생 성공 아니다 샤넬 그 남자',
#  '영화 내용 없다',
#  '십 수년 세월 찰나 순간 처럼 찰나 순간 영원하다 기억 남기다 시간 상대성 이론 관',
#  '니노 이중인격 연기 두근거리다',
#  '보다 울컥 핫 영화 재미 있다 멀다 감동 적임',
#  '열정 만으로 돌진 하고 싶다 만들다 영화',
#  '연기력 에서 유혹 못',
#  '난감하다 재미 없다 세상 깜짝 놀라다 센세이션 없다',
#  '아무리 노력 차이나타운 대놓고 베 끼다 것 용서 안 되다',
#  '신화 화이팅 에릭 화이팅 모두 힘내다',
#  '엔딩 넘다 슬프다',
#  '영화관 가다 보다 더 좋다 어린시절 로 돌아가다 느낌 들다 만 감',
#  '정말 최고 이다 이민정 씨 신하균 씨 연기 너무 좋다',
#  '몇 안되다 재밌다 보다 영화',
#  '교양 시간 보고 충격 먹다 영화 마지막 너무 슬프다 빨갱이 라 소리 지르다 몬초 갑자기 다른 단어 말 건 선생님 대한 그리움 미안하다 슬프다 몬초 마지막 울먹이다 같다',
#  '보다',
#  '안 무섭다 귀신 애기 라 그런 건 지 그냥 깜놀 뿐 이야',
#  '뭐 쥐 모든 것 다 어설프다',
#  '배우 따뜻하다 연기 일상 힘겹다 움 그리다 현 실감 다 좋다',
#  '남자배우 정말 미스캐스팅 연기력 안습 조은숙 김유미 연 기 땜 참고 보다',
#  '차 세계대전 피고 진 청춘 무기 기술 력 세기 전쟁 일으키다 정치인 전쟁 지휘 고위 장교 생각 세기',
#  '책 과는 분명하다 다른 시선 괜찮다',
#  '내 거 왜 보다 싶다 한예슬 이랑 김태희 나오다 보다 듯 적월 개 쌤',
#  '솔직하다 점때 뭐 냐 약간 더럽다 장면 만 빼다 정도 다',
#  '오다 이연서 님 신인 답지 않다 연기력 자다 보다 다음 작품 에서 또 뵙다 바라다',
#  '반전 전부 아니다 영화 몇 번 보다 또 보고 싶다 영화',
#  '피해자 만 있다 피의자 없다',
#  '개다 멀다 주인공 지 혼자 복수 못 주변 에서 해주다 바라다 민폐 녀 아직도 끌리다 ㅡㅡ',
#  '신선하다 소재 화끈하다 액션 스피디 전개',
#  '영화 박자 디테 이다 정말 시가전 퀄리티 완벽하다 남자 사랑 대한 묘사 작 중 한석규 누군가 사랑 마음 정말 디테 일이 대단하다 마지막 얘기 완 급 조절 완벽하다 영화 정말 멋지다',
#  '탕웨이 찡 그녀 만으로도 점 주기 충분하다',
#  '감동 적 인 영화 다',
#  '당시 대박 치다 영화 괜찮다',
#  '억지스럽다 시나리오 지루하다 전개 편 보다 못 구성 등 편 안 나오다 나다 망작 배우 영 화보 눈 없다 안타깝다',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋ 반도 안되다 영화',
#  '영화 평점 높다 이유 모르다 ㅡ ㅡ',
#  '평생 기억 영화 정상 적 인 소재 아니다',
#  '요즘 상황 보고 영화 생각나다',
#  '많다 것 생각 만들다 영화 이다 마지막 사람 짐승 보이 고 아수라 사람 같다 보이다',
#  '진짜 재미 없다 영화 공통점 스포츠영화 군대 영화 자막 나오다 영화',
#  '로버트 드니 로 광기 복수 연기 만끽 있다 수작 서스펜스 스릴러물',
#  '감동 감동 감동 도가니탕',
#  '세계 어디 서나 정치 경제 문화 사회 전반 걸치다 변화 절실 상황 이지만 변화 가져오다 방법 없다 함정 인 것 같다',
#  '귀엽다 베다 똑똑하다 베다 예쁘다 귀엽다 친구 압삘럽 ㅎ',
#  '당시 개봉 날 보고 울면 서 나오다 돈 아깝다',
#  '정말 최고 영화',
#  '잔잔하다 숨막히다 영화 연출 대단하다 곳곳 숨다 복선 치밀하다 싶다 정도 로 섬세하다 감정 표현 거기 김영애 연기 까지',
#  '시나리오 연출 연기 어느 것 하나 갖추다 못 시간 넘다 아깝다 억지 싸구려 중국 신파 경극',
#  '거부 몸짓 저 하늘',
#  '그만 빙빙 돌리다 밝혀지다 안되다 보다 아직도 질질 끌다 짜증나다 안 보다 여기 서 또 사고 터지다 또 질질 끌 면 진짜 짜증나다 빨리 빨리 밝혀지다 밝혀지다 반전 있다 작가 님 드라마 사랑 하고 재다 넘다 끌다 짜증나다',
#  '졸다 보다 왜 이리 평정 높다 겨 내용 별거 없다 아오 감수성 영화 냐 거',
#  '기대하다 않다 영화 아름답다 움 밀려오다 꽤 괜찮다 영화',
#  '진짜 번만 더 이런 영화 상영 용서 않다 지금 영화 보다 카톡 하고 잇다 아 놓다 진짜',
#  '살다 있다 생동감 잃다 박물관',
#  '노땅 한심하다 추억 미화',
#  '어리다 적 눈물 흘리다 웃다 기억 간신히 찾다 다시 보다',
#  '인종차별 유괴 라는 두 주제 불협화음',
#  '고명환 연기 쩌 냐 아니다 돈 없다 쓸다 후자 라면 보다 없다 영화',
#  '속편 에서는 주인공 전작 처럼 앨빈 밴드 이다 좋다 같다 캐릭터 추가 로더 이상하다',
#  '혼자 보다 너무 아깝다 년 올해 영화',
#  '마지막 결투 씬 최고 폭풍눈물 팝핀현준 할아버지 ㅋㅋㅋ',
#  'ㄵ 점 대',
#  '좋다 상술 최고 아니다 선거 술 최고',
#  '쓰레기 함부로 버리다 맙시 다',
#  '글쎄 나 와는 안 맞다 성향 영화 중 하나 늘다 들다 만 함',
#  '즐',
#  '막장 재미 있다 보지 재미 없다 짜증 만 남 남녀 주인공 어울리다 참고 보다 진짜 안 어울리다 웬만하다 다 재밌다 보다 진짜 내 가보다 중 제일 최악 이다 무 틀다 주인공 부터 시작 성격 개 이상하다 조 기 종영 답 이다',
#  '줄리 델피 나이 들다 멋지다',
#  '내 보다 일드 중 쵝오',
#  '역시 명작 명작 이다',
#  '글쎄요 뭐라다 영화 제목 잘못 보고 착각 내 잘못 랄 끄다',
#  '그냥 기독교 영화 네 요 더 깊이 있다 내용 기대하다 실망 이다 영화 뭔가 엉 성해 요',
#  '그냥 책 읽다 더 절절 다가오다 영화 내용 너무 비약 하고 삭제 행간 잃어버리다 책 에서 꽉 차다 느낌 반대 로 모든 것 엉 성하다',
#  '너무나 감동 적 인 영화',
#  '스킨헤드 성 님 들이다 영화 싫어하다',
#  '자동차 매니아 인 나 평점 점 이하 속 았 다 아오',
#  '나 거 보고 인형 절 대안 삼',
#  '정체 성은 사치 인가',
#  '나이 먹다 아저씨 일찐 놀이 영화 개 역겹다 알바 풀다 현 실감 개 진짜 개제 로',
#  '남극 오다 그만 길 잃다 오르다 못 곳 오르다 것 아니다',
#  '재밌다 귀엽다 신나다',
#  '포스터 진심 개 쩐다 엑소시스트 능가 공포물 같다 실상 처키 보다 못 영화',
#  '시청률 늘다 개뿔 존 나 재미없다 제보 니 가다 사극 너무 못 만 드 네',
#  '요즘 재방 보다 넘다 재밌다 왜 시청률 저조하다 싶다 두다 귀요미',
#  '연출 연기 영상 아름답다 영화 이다 저예산영화 인 관계 로 스펙 타 크다 부족하다 한국 영화계 새롭다 바람 희망 다크호스 되다 임 믿다 많다 응원 부탁드리다 벌써 부터 일찍 관람 해주다 신분 진심 감사하다',
#  '평점 왜 이렇게 낮다 난 거 또 다운 받다 번째 정말 재다 끝 견자단 하고 대 빵 하고 싸우다 땐 정말 가슴 뜨겁다 난정 말로 재다 보다 최근 댓글 이니 내 알바 아니다 알다',
#  '게 어떻다 평점 낮다 있다',
#  '블랙코미디 조롱 대상 우린 데 기분 드럽다 점수 주다 성기 노출 등 어그 로나 끄다 ㅉㅉ',
#  '촌 동네 조폭 삼류 영화 가끔 씩 툭툭 밉다 유머 영 쌩뚱 맞다 촌스럽다',
#  '점 만들기',
#  '스타 뎀 형님 얼굴 먹다 칠 영화',
#  '헐다 남자 몸매 보다 기분 좋다',
#  '안 보다 별 점 한개 주다 류 영화 같다 심형래 아저씨 동 급 감독 인 듯 ㅋㅋㅋ',
#  '정말 완벽하다 최고 영화 중 꼽히다 영화',
#  '조잡하다 유치하다 저 예산 류 급 영화 다 스토리 깊이 감다 없다 전체 적 루즈',
#  '진짜 뭐 냐 민국이 나 지아 더빙 더 이상 시키다 안되다 더빙 얼마나 중요하다 이런 애 시키다 데뷔 도안 애 연예인 이해도 뭐라다 판',
#  '그냥 재미 없다',
#  '쇼 해 라 쇼',
#  '중심 약하다 언 저리 가지 고 무리하다 승부 수 띄우다',
#  '주 연 배우 이름 만 기억 남',
#  '그냥 안 보다 이득',
#  '키 기키 기키 기키 기키 기',
#  '박얘쁜 빠수니 죄다 없어지다 버리다',
#  '진짜 짜증나다 영화',
#  '불 자다 보이지 않다 사람 죽다 나가다 때 엄청나다 웅장 음악 만 나오다 전혀 마음 오다 닿다 않다 설정',
#  '망작',
#  '상당하다 재밌다 보다',
#  '내 코끼리 내놓다 더 재밌다 ㅋ',
#  '코믹 코믹 보다 패러디 하고 카메오 들보 재미 있다',
#  '유치 짬뽕 이네 딱 초등 학년 영화 다 초등학교 자녀 있다 가족 분 께 추천 함',
#  '후속 지금 이라도 나와라 한국 애니 살리다 보다',
#  '통해 보다 정말 재밌다 자다 보다 요 근래 보다 영화 중 최고 인 듯',
#  '기대 않다 보다 찰지다 만들다 토종 느와르 네 흥미진진',
#  '성인영화 가족영화 로 만 드리다 멍청하다 자막 제작자 마음 안 들어서다 점',
#  '일본인 특유 어색하다 연기 여 주인공 연기 너무 못',
#  '전반 적 무겁다 느낌 영화 네 요 가비 의향 맛 처럼 씁쓸하다 느껴지다 장윤현 감독 님 께서 커피 부분 관해 신경 쓰시 다 보다 연출 부분 있다 미흡하다 않다 배우 연기력 괜찮다',
#  '전작 보다 재밌다 배우 내용 모두 세련되다',
#  '진지하다 무겁다 소재 경쾌하다 재미있다 만들다',
#  '유럽 작품 상 탈 만 유럽 중요하다 얘기 또한 픽션',
#  '풍 정정은 어케된거 지 ㅋㅋㅋ 과도 압축 개연 성 없다 배우 호화롭다',
#  '이영화 구성 좋다 분 아마 친구 랑 같이 영 화보 고 님들 영화 좋다 재밌다 같다 이본 친구 이해 못 겁니다 진짜 최악 최저 스토리 주인공 행동 개연 성 없다 캐릭 간 이해관계 최악 ㅋㅋㅋ 갘 이렇게 허다 접다 표현 되다 영화 간만 이라 능 ㅋ',
#  '젠 그만 보고 싶다 막 돼다 먹다 스토리텔링',
#  '말 필요 없다 로맨스 싫어하다 내 보다 때 기절 것 같다 ㅜㅜㅜㅜ',
#  '제 취향 적 이고 우울하다 마음 완전하다 날다 버리다 슬프다 내용 본 뒤 마음 정화 시키다',
#  '영상 미가 역시 최고 네 요',
#  '끙',
#  '역시 한국영 화 보다 돼다',
#  '괜찮다 영화',
#  '요즘 재밌다',
#  '소재 차다 좋다 삼 점 주다 제작 되다 영화 공포 스릴러 아니다 본분 잊다 드라마 아니다 드라마 같다 느낌 이다 연기 연출 괜찮다 다만 시작 부터 끝 까지 지루하다 뿐 이다 또 어떻다 장면 살짝 유치하다',
#  '남자 인데 보다 울다 딸 낳다 해주다',
#  '안타깝다 뿐 안타깝다 뿐',
#  '영웅 사람 원하다 때문 만들어지다 또다른 희생 다',
#  '그냥 평작 욕 까진 안 나오다',
#  '극 장가 서 안 보다 내 머리 깨 버리다 제 인생 최고 영홥니 다 키이라 작품 중 에서도 최고 이다 알럽키 이라',
#  '중고생 마마 추어 포르노',
#  '비디오 물이 냐 동시 상 영물 이냐 넌 정체 모 냐',
#  '이건 말로 설명 수 없다 유치하다 진짜 필름 아깝다',
#  '이승연 강렬하다 묻다 영화 그러나 홍경인 너무 불쌍하다 나오다',
#  '드릴 브라 에서 뿜었다',
#  '부족하다 영화 아니다 부족하다 영화 감동 있다 참고 끝 까지 다 보다 진심 이렇게 재미없다 느끼다 처음',
#  '계몽영화 한계 고스 란 답습',
#  '우와 정말 오랜 만 통쾌하다 웃다 내일 기대 되다',
#  '청춘 에는 마침표 없다',
#  '세얼간이 아줌마 나오다 한번 보다 실망 신선하다 반전 주다 보다 개연 성도 없다 뭐 이렇다',
#  '좋다 소재 만족하다 연출',
#  '심혜진 나오다 겨우 저 정도 라니 실망 이다',
#  '아들 놈 끝 까지 아빠 한테 미안하다 감정 없다 ㅠ 소재 신선하다 영화 자체 메시지 모호하다 스토리 짜임새 있다 않다 것 같다',
#  '창업 꿈꾸다 좋다 아이템 있다 사업 그렇다 기르다 쓰다 영활 보기 바라다 그 멀다 험하다 여정 스승 되다 지침 서 가다 되다 혹은 단념 도움 되다 차다 오랜 만 박 장 대소 하 며 보다 독립 영활 세',
#  '슬프다 액션영화 치고는 실망 이크 다 부자간 배신 원망 끝나다 너무 허무하다',
#  '명화 에서 거 보고 움 진짜 감동 적',
#  '낰였다 티 프리미엄 ㅡㅡ 인간 적 인 면 쫌 맘 들어서다 점 주다 근데 진짜 이선균 정재영 김상중 연 기 파 배우 불다 코 이딴 쓰레기 영화 찍다 ㅡㅡ 진짜 영화 보다 계쇠 지루하다 괴롭다 ㅡㅡ',
#  '너무나 따뜻하다 감동 적 인 영화',
#  '급 영화 안되다 일 점도 아깝다 네이버 마이너스 점수 만들다 달라',
#  '스토리 부진 액션 재미 까지 반감 시키다',
#  '누구 나 ㅡ 끼다 ㅣㅆ 느덕 영화 화하다 굿',
#  '시종일관 오락가락 말 뭔 지 모르다 감독 자기 만의 세계 빠지다 만들다 같다 영화',
#  '왠 지모 색다르다 감동 주다 영화 이다',
#  '전 주 영화제 에서 보다 데넘 늦다 개봉 듯 종교 업 대해 한번 더 생각 들다 영화 저 예산 으로만 들다 감독 노력 느껴지다 크다 박수 보내다 화이팅',
#  '보다 웃다 재밌다',
#  '사랑 상처 받다 다시 치유 되다 있다 생각 들다 영화',
#  '극 장가 서 본 영화 중 쓰다 쓸다 아픔 처음 느끼다 해주다 퍼스트',
#  '최고 더 무슨 평가 필요하다 탑',
#  '자신 삶 대해 다시 한번 생각 영화',
#  '알바 놈 양심 없다 멀다 보고 십 점주 거 냐',
#  '년도 로 돌아가다 해주다 ㅡㅡ',
#  '끼우다 맞추다 개 쩔다 반전 하나 보고 오다 인간 이해 불가',
#  '우웩 개 랑 무슨 짓 후세 태어나다 일 본 놈 진짜 정신 상태 이상하다',
#  '영활 보다 흐뭇하다 영화 한국 더 만들다 걸 느끼다 되다',
#  '지다 들이다 뭔 데 대우 깔다',
#  '재밌다 짠하다 그게 매력 이다',
#  '오다 내 머릿속 지우개 이후 진짜 슬프다 영화 이다 마지막 눈물 폭발 ㅜㅜ 오늘이 후 에도 또 보다',
#  '월요커플 짱짱 덕분 아주 재미있다 보고 있다 습 니당다',
#  '터키 특집 액션 스키 추격 기억 남고 소 피 소 피 의하다 소 피 위 시리즈 로 저 무어 시절 보다 재미 조금 떨어지다',
#  '수많다 최루성 멜로 여기 에서',
#  '내 평생 최고 걸작 현실 건너편 세계 잠시 엿 본 듯 느낌',
#  '내 인생 최고 영화',
#  '진짜 추천',
#  '포스터 사기 너무 현실 적 이어서 배우 심각하다 빵빵 터지다 화 성남 금 성녀 아 슈발 지다 혼자 내리다 본 전 생각 담배 피다 남편',
#  '머 마술 이라는 거 야 나 죽다 외계인 만 나볼 수나 있다',
#  '차다 재밌다 영화',
#  '빨 리좀 끝나다 으이 그 처음 엔 재밌다 알다 뭐 야 이리 재미없다',
#  '극 전혀 몰입 안되다 장면 이다 붙다 이기 식 단순 진행 연출 력 형편 없다',
#  '자막 제작자 써다 막장 임',
#  '그리다 무섭다 수도승 물 쉬다 떠내려가다',
#  '게왜 주온 보다 평점 높다 이해 가안 간다 이영화 맨 처음 여배우 물대포 쏠때 부터 웃겻다 포스터 더 무섭다 영화상 영 시간 내내 포스터 만 보여주다 충분하다 린다',
#  '진짜 신기하다 라는 말 밖에 안나',
#  '좋다 배우 데리 고 작품 부족함',
#  '아니다 왜 점 대 라니 근래 보다 다크 히어로 무비 중 에서 최고 이다 아주 그냥 고스트라이더 에게 걸리다 스치다 사망 인거 에요',
#  '묵직하다 시작 울다 끝나다',
#  '내용 전개 엉 성하다 지루하다 정도 로 재미 없다 슴',
#  '돈 뭉치 로 싸대기 명 장면 이다',
#  '고고 ㅋㅋㅋ',
#  '쓰레기 영화',
#  '너무 일찍 슬픔 알 게 되다 제제 안쓰럽다 책 읽다 눈물 나다 영화 마찬가지 다 어리다 제제 슬픔 너무 일찍 알 아 버리다',
#  '정말 비디오 마저 돈 주다 보고 아깝다 최악',
#  '말 그대로 뚝방 에서 볼 영화',
#  '내 인생 최고 영화 년 다 되다 아직도 아련하다 애틋하다 기억',
#  '감독 ㅡㅡ 다시다 영화 찍지마라',
#  '육감 적 인 섹시하다 여인 존재 자체 영화 전부',
#  '영화 첫 도입 부 부터 카메라 각도 라든지 화질 이라든지 겁나다 구림 영화 아니다 알다',
#  '진정 좋다 영 화란 볼때 당시 재다 있다 두고두고 기억나다 생각나다 또 한번 쯤 보다 이런 영화 아닐런지 요',
#  '박사 아들 정시 현 정말 멋지다',
#  '편이 너무 좋다 편이 너무 묻히다',
#  '말 없다',
#  '난 별로 던데',
#  '이렇다 영화 차다 좋다',
#  '곳곳 번뜩이다 아이디어 아기자기하다 구성 돋보이다 수작',
#  '우아 새벽 보 니까 무섭다 ㅠ ㅠ 미스터리 에로스 스릴러 겸비 영화',
#  '짧다 정말 재밌다 보다 윤계상 능청 연기 좋다 되다 생각 계속',
#  '에린 초반 타다 차 현대 자동차 프레스토 네요 보다 추억 세다 세다',
#  '남 철학 적 인 영화 라 고도 하지만 단순 액션 용 보다 정도 점수 나오다 되다',
#  '효과음 기 막히다 영화',
#  '솔직하다 평점 점 이상은 되다 되다 같다',
#  '난 강혜정 일 본가 서 찍다 건가 닮다 같다 생각 들다 뿐 이고',
#  '일본 영화 좋아하다 꼭 보다 야하다 영화',
#  '진짜 이건 아니다 ㅋㅋㅋㅋㅋ 액션영화 좋아하다 액션영화 만 다운 받다 꾸준하다 보다 벌써 몇 년 인 사람 임 근데 이건 진짴 ㅋㅋㅋㅋㅋㅋ 아무리 점수 자다 주다 점 만점 점 ㅡㅡ 돈 주다 보다 너무 아깝다 진짜 ㅜㅜ 그리고 대체 왜 구역 타이틀 달고나 오다 모르다 실망',
#  '가슴 먹다 먹다 뷰욕 왜 이제 서다 알 게 돼다',
#  '커스틴 때문 좋다',
#  '보다 찝찝하다 영화 끝나다 나서다 불쾌하다 중년 남성 이렇게 까지 추잡하다 보이다 수가 있다',
#  '진짜 퀵이유 로 이렇게 어이없다 재미없다 영화 처음 이다 진짜 돈 아깝다 적다 두번째 라',
#  '진짜 재미없다 영화관 삼십분 정도 늦다 들어가다 사람 명도 없다 그 이유 왠지 알다 같다 완전 비추다',
#  '년 본 영화인 대 솜 이랑 키 작다 남자 살다 나가다',
#  '조금 유치하다 왕조현 주윤발 것 만으로도 충분하다 볼 만',
#  '난 솔직하다 재미없다 코믹 요소 없다',
#  '싸구려 왜색 영화 키 작고 교활하다 일 본 원숭이 망상 사무라이 정신 토나오다',
#  '재미있다 봄 감동 적 이고',
#  '아니다 찍다 모니터링 한번 안 하나 어떻다 염치 업 이런 걸 극장 걸다 있다',
#  '영화 산업 이라고 이딴 식 홍보 속 여서 파다 게 소비자 입장 에서는 짜증나다 그나마 다행 아주 싸구려 상급 품 속 여 판 게 아니다 점 그래서 점 차라리 연 상호 감독 작품 처럼 홍보 돼다 그 비슷하다 만이라도',
#  '완전 감동 이다 박신혜 짱 이쁘다',
#  '절망 속 에서 결국 빠져나오다 눈물 기다 실화',
#  '국민학교 다니다 때 거 동생 이랑 보다 눈물 ㅋ',
#  '욕망 이라는 이름 전차',
#  '디 워 랑 같다 부류 저 예산 저렴하다 마구잡이 연출',
#  '무기 여 자다 보다 내내 손 땀 쥐 고본 첫 번째 애니',
#  '배우 연기력 아깝다 별 개도 아깝다',
#  '딱 년대 코미디 영화',
#  '어리다 때 진짜 재미있다 보다 ㅋㅋㅋㅋ',
#  '정말 최고 영화 고 마지막 아이 노래 비행기 정말 잊다 없다 여운 남기다 이렇다 영화 제 알 게 되다 자체 후회되다 정도 로 잔잔하다 깊다 여운 남다 영화',
#  '보다 어이없다 헛웃음 만 나다',
#  '악역 인 금단비 더 주목 받다 주 연 여배우 미스캐스팅 의미',
#  '보고 나서다 내내 여운 남다 영화',
#  '절대로 보다 보다 후회 다 걸 영화 라고 만들다 볼 사람 뇌 놓다 보아 라',
#  '무슨 내용 인지 도통 모르다 쓸데없이 특별하다 보이다 시도 에만 열중 이다 영화',
#  '기쁨 슬픔 생명 그리고 죽음 인간 역사 속 거대하다 하나님 우주 적 섭리 느껴지다 영화 특별하다 어머니 역 맡다 여배우 여 성미 자애 로움 인상 적 이다 인생 살다 그렇다 존재 되다 영 상미 예술 이다',
#  '게 뭔 가요 내 용도 없다',
#  '평점 어마어마하다 높다 빨리 낮추다 점 적당하다 영화',
#  '이야기 보통 재미있다 점 정도 아니다 보다 점 점 정도 인데 고릴라 제 작 거도 하지만 감동 보통 아쉽다 결말',
#  '솔직하다 웬만하다 공포영화 다 섭렵 매니아 인데 주온 정말 무섭다 아직 까지도 샤워 머리 감 때 공포 느끼다 누가 나르다 쳐다보다 있다 느낌 이라서 느낌 나 말고도 겪다 본 사람 있다 그만큼 당시 대단하다 영화 다',
#  '아름답다 영화 이다',
#  '정말 광해 비슷하다',
#  '조 쉬 하트넷 특유 여성 자극 나약하다 남성 적 인 이미지 작 부각 듯',
#  '정말 속 느낌 이다',
#  '몸매 베드 신 보기 좋다 사람 영화 안 본 사람',
#  '보다 외모 뿐 만이 아니다 여러가지 따다 사랑 빠지다 아니다 요즘 사람 에게 좋다 영화 인거 같다',
#  '최악 쓰레기 어설프다 정말 노력',
#  '콜린 파렐',
#  '난이 게 제일 재밌다',
#  '난 좋다 괜찮다',
#  '영화 보다 댓글 더 재밌다',
#  '라이 미치다 사이코 드라마 야',
#  '모든 일 본 문화 들어가다 있다 수 있다 최고 사극',
#  '엄청나다 기대 보다 아니다 괜찮다',
#  '더빙 똥 이야',
#  '안타깝다 이해 못 사람 속출 불교 적 이고 철학 적 인 작품',
#  '진짜 이렇다 개 씨 바 ㄹ 같다 영화 개 시간 낭비 의미 없다 무섭다 않다 내 왠만하다 공포영화 즐기다 보다 이건 진짜 같다',
#  '색다르다 재밌다 영화 이다 실제 로 이렇다 일이 있다 차다 재밌다 것 같다 막장 막장',
#  '어캐봐 여 꼬옥 보다',
#  '정말 식상하다 촌스럽다',
#  '종교 적 분위기 물씬 풍기다 최루성 가족영화',
#  '재밌다',
#  '그냥 살 지 그렇다 이성재 만 멋지다',
#  '음악 영화 라 나 에겐 취향 저격 이지만 비긴 어게인 처럼 대중 적 흥행 힘들다 영화 네 요 하지만 여주 너무 매력 적 이에요',
#  '별 개 선택 왜 없다 솔직하다 별 반개 아깝다',
#  '돈 미치다 남편 아기 미치다 돈 있다 남자 그 속 에서 갈등 여자',
#  '어린이 시점 에서만 볼 만 오로지 어린이 시점',
#  '잠 청 수 있다',
#  '좋아하다 사람 뇌 아니다 완전 난해하다 결말 왕 실망 임',
#  '전작 비 왠지 허탈하다 카이사르 전작 더 멋있다 듯',
#  '김민종 최고 더 되다',
#  '공격 적 인 재미 유순하다 여성성 일기토 지략 삼국지 그것 맞짱',
#  '점수 주다 싶다 년 이정 밖에 못 만들다 충격',
#  '비디오테잎 좍좍 감다 보다 영화 가장 슬프다 영화',
#  '도입 부르다 제외 하고는 따분 헬기 에서 민간인 마구 쏘다 죽이다 미군 베트공 여성 스나이퍼 등 현 실감 없다 극단 적 인 설정 라이언 일병 에서의 업햄 그리고 영화 주인공 인 조커 두 넘다 모두 내 싫어하다 캐릭터 착하다 척 주위 피해 주다 넘다 들다',
#  '재밌다 나 만 그 런가 참고 로 우리나라 끄다 하나 안 나오다 그냥 지다 들다 끼리 소설 쓰다 지다 들다 끼리 자위 하고 자위대 등장 그 사람 자위 나 있다 일본 감정 다 떠나다 과학 로써 과학 적 볼 만 영화 이다 신선하다',
#  '제 취향 아니다',
#  '평점 조절',
#  '점도 아깝다 쓰레기 영화 전작 아깝다 움',
#  '일편 비다 삽질 브리 짓 쪼 끄다 짜증나다 때 있다 그래도 여전하다 사랑스럽다 ㅎ 콜린 퍼스 휴 그랜트 한자리 모으다 것 만으로도 점 주다 야하다',
#  '지금 까지 보다 아이리스 시리즈 중 최악 이다 거 해도 너무하다 아니다 수치 스럽다 연기 고 자시 고 다 떠나다 너무도 허다 접합',
#  '연기력 때문 없다 정우성 고소영 왜 그토록 흥행 작 없다 알다 비트 에서 연기 보다',
#  '전라도 노예 업주 처벌 안 받다 이슈 가안 돼다 그렇다 보다',
#  '배우 아깝다',
#  '볼 만 한데',
#  '결말 의미 공자 자연 숨다 살다 노자 에게 말 짐승 끼리끼리 살다 사람 이라고 따로 사다 진정 순수하다 더럽다 사이 에서도 그 빛 유지',
#  '크리스 터 크다 짱 이삼',
#  '믿다 보다 덴젤와싱턴 근데 모레쯔 왜 이렇게 후덕',
#  '나오다 코 진짜 집중 안되다',
#  '감독 밥 먹다 다니다 궁금하다 배틀로얄 이후 로 최고 쓰래 기',
#  '아 재미 너무 없다 시간 아깝다',
#  '난 재다',
#  '어떻다 상류층 속물 근성 정당화 시키다 미화 시키다 모르다 감독 국회의원 이나 사회 적 강 한테 아부 하고 싶다 가보다 그리고 얼굴 만 예쁘다 왕 되다 맞다 드라마 라도 도덕 적 표현 되다 아니다 감독 님 정신차리다',
#  '가만히 보고 만 있다 씨익 웃음 나 행복하다 가족 이야기',
#  '사고 후 잠시 정상인 되어다 일 탈',
#  '좋다 영화',
#  '거 예전 에나 오다 같다 재미 네',
#  '샬라샬 라 나오다 즁 쥬 아',
#  '감독 옹졸하다 치졸하다 묻다 영화',
#  '팔 빠다',
#  '재미없다',
#  '무슨 생각 만들다 걸다',
#  '스토리 흥미 롭고 배우 연기 인상 적 이다 충분하다 볼 만하 다',
#  '내 인생 최고 미드',
#  '영화 보고 사랑 하고 싶다 라는 생각 청소년 관람 불가 임 에도 선정 적 인 장면 나오다 않다 연인 혹은 솔로 이신 분 에게 추천',
#  '일 본 공포영화 링 주온 이후 로 망하다',
#  '지루하다 지루하다',
#  '직접 겪다 어르신 얘길 들다 보다 그 당시 잔인하다 학살 대부분 주민 서 로간 주로 하층 민 복수심 에서 비롯 되다 또는 군 경이 빨치산 학살 벌이다 살인 이다 정작 북한 군 민간인 한테 늘다 해주다',
#  '그냥 다큐 일 뿐',
#  '점 짜다 영화 아니다 개인 적 으로는 평균 평점 점 정도 가치 보다 스타 일리 쉬 영화 ㅋ',
#  '정말 질질 끌 고 작가 님 제발 적당하다 은희 수역 맡다 사람 그만 나쁘다 만들다 아침 드라마 막장 이네',
#  '으이구 괴물 그래픽 이나 다듬다 그게 멀다 다 티나 게 공포영화 보다 웃다 건 첨 이다',
#  '대표 적 인 쓰레기 김치 드라마',
#  '네이버 별 점 꽤 신뢰 높다 점 이하 안 보다 좋다',
#  '남다 헤어스타일 왜 저렇다 가게 분신 노찌 쯔',
#  '이런 영화 두 번 보다 안다 작다 일 에도 크게 화 만들다 저 나라 국민 인상 깊다',
#  '김명민 약 구해 서 차 타다 때 진짜 설마설마',
#  '보다 재미있다 재미없다 진짜 찝찝하다 기분 드럽다 영화 공포영화 싸이코 영화',
#  '짝퉁 쓰래 기',
#  '거 시청률 너무 낮다 명작 고만',
#  '현 실감 제로 지만 배우 너무 좋다 특히 다니엘헤니 많이 볼 수 있다 좋다 같다 남자 지만 게이 아니다 다니엘헤니 최고 설경구 씨 두 최고',
#  '프레디 나 에게 모욕감 주다 그래도 프레디 라서 점 주다',
#  '잼 없다 넘다',
#  '평점 너무 높다 원작 보심 나다 짧다 러닝 타임 감사하다 주인공 썰매 타고 목적지 가다 모든 사람 기억 돌아오다 황당하다 설정 이고 인간 감정 통제 한다는 건 데몰리션맨 이퀄리브리엄 에서 보다 때문 신선하다 없다',
#  '막장 드라마 원조 격인 영화 근데 영화 확실하다 로 즈 번 살리다',
#  '해군 출신 이라 관심 있다 보다 영화',
#  '파란색 슬픔 영화',
#  '액션 완전 기 차라리 유오성 나오다 챔프 보다',
#  '폭풍 오열 ㅠㅜㅠㅍ 퓨 ㅠ',
#  '착하다 영화 그리고 재미없다',
#  '사소하다 이야기 조차 눈 떼다 없다 만들다 거장 솜씨 예전 장 이모 우 그리다',
#  '내 가보다 영화 중 베스트 안 듬 진짜 꼭 보다',
#  '지금 까지 보다 페이크 다큐 영화 중 제일 별로',
#  '재미 있다 공감 되다 누구 나 즐기다 독립영화',
#  '시미즈 레이 코 만화책 비밀 에서 영향 받다 알다 똑같다 애',
#  '기존 한국 영화 에서 느끼다 못 색다르다 느낌 상 업적 이기 보다는 새 로움 도전 듯',
#  '장난 하나 반전 같다 있다 줄 알 고 끝 까지 다 보다 진짜 아오 시간 아깝다',
#  '예고편 왜 건지다 모르다 예고편 나오다 하나 안 나오다 예고편 대판 쌈질 마냥 나오다 하하호호 끝나다 예고편 무슨 뜻 인지 모르다 건지다 시청자 호구 로 보다 건지다 낚시질 그만하다 차라리 시청률 걱정 되다 폐지',
#  '난 프랑스 영화 이래서 좋다',
#  '쓰레기 쓰레기 쓰레기 쓰레기 쓰레기 쓰레기 쓰레기 쓰레기',
#  '차다 재밌다 보다 귀엽다 지미',
#  '시간 지나다 또 보다 정말 가슴 애린 드라마 ㅠ ㅠ',
#  '사촌동생 때문 같이 보다 정말 사촌동생 재미없다',
#  '설득 력 없다 꼴통 페미니즘 페미나치 적 인 마인드',
#  '급 지향 급 작품',
#  '음 자다 모르다 뭘 보다 건지다 소녀 가장 이야기 인가',
#  '우리 틀리다 생각 장애인 우리 틀리다 않다 단것 알다',
#  '재밌다 감각 있다 쿨하다 영화 이다 마지막 결말 약간 아쉽다',
#  '그냥 재미없다 보다 마저 보다 이랬는데 갑자기 원주민 생활 진짜 어처구니 없다 이건 그냥 영화 아니다',
#  '진짜 언제 분 지나가다 모르다 정도 로 몰입 보고 정말 너무 재미있다 봄 너무 아련하다 영화 평 정말 처음 남기다 봄 진짜 내 나이 애니 보다 밤중 이렇게 울다 에몽 아',
#  '사과 나 한테',
#  '골목 상권 들어오다 대형 슈퍼마켓 생각나다',
#  '평점 조절 필요하다 라는 생각 들다',
#  '무협 멜로 걸작 말 모해',
#  '너무 재미있다 보다 다시 보다 없다',
#  '오글거리다 유치하다 완전 최악 이다',
#  '절대 비추다',
#  '한국 껀줄 알다 일본 꺼 엿 네',
#  '꽃 한송이 놓다 가다',
#  '내 삶 가장 의미 있다 일 중 하나라 면 바로 영화 보다 것 이다 살다 죽다 전 한번 꼭 보다 영화',
#  '생각 보다 볼 만 ㅋ 여 주인공 연기 좋다 네 여',
#  '자꾸 뭘 설득 려 하고 설교 보기 거북하다 그리고 결혼반지 위해 범죄 담하다 무슨 개역 지 설정 이냐',
#  '오다',
#  '제발 전 문성우 써주다',
#  '살다 처음 접 해보다 장르 라서 조금 당황 스럽다 솔직하다 영화 자체 자신 색깔 충실하다 완성 역시 뛰어나다 편이 지만 좋아하다 이해 못 ㅋ',
#  '오늘 아이 데리 고 보다 아이 좋아하다 미취 학 초등 어린이 에게 추천',
#  '것 끝 까지 참고 보다 내 제일 자랑스럽다',
#  '존내 재밋습 네 다',
#  '안 보다 되다 영화',
#  '원작 망치다',
#  '그냥 주다 점 아니다 듯',
#  '나쁘다 않다 개인 적 으로는 지루하다',
#  '어의 없다 스토리 여자 죽 때 웃음 나오다 로맨스영화 냐',
#  '순수하다 두근거리다 좋다 감독 님 관객 뭘 원하다 잘알다 여운 많이 남다',
#  '기 방 난 동 사건 이후 최악 영화 재밌다 사람 믿다 보다 다 알바생 인 듯 ㅜㅜ',
#  '로맨스 스릴러 짬뽕 놓다 뭘 말 하고 싶다 건지다 스토리 허황 되다 느낌',
#  '이건 아니다',
#  '윤아 안되다 원 작자 님 캐스팅 참여 해주다 작품 망치 면 안되다',
#  '지금 생각 해도 내 가보다 영화 중 이영화 내 생애 최고 영화 이다 같다',
#  '천녀유혼 비 뭐라다 표현 힘드다 퀭 영화',
#  '불륜 미화 영화 남다 사람 어쩌라고 또 돈 걱정 따위 안 사람 이야기 공감 하 라고 강요 영화 음악 이랑 영상 미로 점',
#  '최고다 이란 노래 원 곡 보다 영화 속 노래 훠 얼씬 좋다',
#  '소재 굉장하다 신선하다',
#  '내사 랑 키 아누 리브 스',
#  '두 말 나위 없이 최고 작품 인생 대해 서 생각 해보다 깊이 있다 영화 전 출연 진과 제 작 진 에게 크다 박수 보내다',
#  '솔직하다 산만',
#  '말 필요없다 성룡 영화 에선 무언가 다른 것 느끼다',
#  '화학 그렇다 잼 잇다 봣습니닼 ㅋ 옆 친구 중간 중간 노 이해 나중 해석 잼잇엇숩니 다',
#  '아직 준비 되다 않다 젊다 영화인 여 함부로 장편 손대다 마라천 천하다 공부 하고 나와라',
#  '으 엉 간만 추억 돋다 보다 사실 원작 자체 두서 없이 전개 되다 영화감독 내용 앞뒤 없이 막 자르다 정신 없다 ㅇ 배우 책 읽다 특히 대사 그대로 살리다 오그리다 그 링 ㅋㅋㅋ 간만 소설 로 읽다',
#  '개 쓰레기 같다 것 아 감히 파라 노말 엑 티비 티 팔 아 먹다',
#  '기억 조작 되다 마련 그 사람 아니다 함 부러 말 말',
#  '재밌다 보다 그저 문헌 적히다 문란하다 사도세자 아니다 정조 아버지 로서 그 그릇 어느 정도 이다 자다 보여주다 작품 아니다 싶다 시나리오 시나리오 지만 배우 연기 일품 이다',
#  '휴일 낮 침대 눕다 티비 보다 가다 영화 채널 에서 틀어주다 어쩔 수 없이 보다 나중 에는 벌떡 앉다 보다 영화 완전 몰입 되다 나름 스토리 치밀하다 해리슨 포드 다운 액션 좋다 저 영화광 영화 평론가 아니다 영화 자주 보다 일반 남자 사람 임',
#  '절제 미학 아니다 지루함 극치 되다 버리다 안타 가다',
#  '영화관 에서 보기 엔 돈 아깝다 솔직하다 재미없다 ㅜㅜ',
#  '인간 솔직하다 보이다 주다 싶다 이렇다 방법 말고도 다른 방법 충분 있다',
#  '정말 사랑 대해 다시 생각 거 같다 감동 이에요',
#  '내용 교육 적 이나 정말 지루하다 ㅜ',
#  '꿀잼 특히 소유 랑 서인영 ㅋㅋㅋㅋ 매력 터지다',
#  '태어나다 보다 영화 중 제일 재미없다',
#  '화면 흑백 바꾸다 년대 작',
#  '쇼핑몰 안 에서만 찍다 너무 재미없다 답답하다 내용 없다',
#  '진짜 쓰레기 영화 돈 아깝다 죽다 알다 여러분 보지 말다',
#  '와아 오 두근두근 익스트림 자체',
#  '폭력 영화 자극 적 이고 실험 적 이라고 예술 인가',
#  '일 본 영화 랑 비슷하다 저만 느끼다 가요 수트 입다 미남 으루 변하다 마지막 평생 입다 구 권유 받다 창조 이렇게 까지 중복 되다 있다 눈 건지다 자다 모르다 겠다',
#  '진짜 이렇게 재미 없다 감동 없다 영화 처음 이네 특히 나 박사 고 나발 이고 모든 인물 컴퓨터 때 손 찍다 키 보드 누르다 않다 ㅋㅋㅋ 컴퓨터 화면 똑같다 파트 만 무한 반복 되다 허다 접 해도 너무 허다 접다 배우 연기 개떡 이고',
#  '최고 농촌 드라마',
#  '독립영화 실력 스타 리그 옴니버스 라는 피로 감 극복 되다 수준 이다 얼음 강 단독 장편 만들다 좋다 듯 주인공 혹 여 평소 라면 공감 안되다 여호와 증인 이라도 납득 되다 정도 로 감정 설득 솜씨 탁월하다',
#  '좀비 좀비 그렇다 좀비 아니다 우주 아름답다 움 미치다 버리다 인간 일 뿐 충분하다 가능하다 일이 죠',
#  '개 재미없다 막장 스토리 어거지',
#  '뭐 하나 흠잡다 것 없다 최고',
#  '가다 좋다 영화',
#  '탁재훈 나오다 믄 재밌 늘다 와이 라지 스토리 중반 부터 너 무치다 짐 약하다 약하다 약하다 지겹다 뒈지다 알',
#  '서스펜스 없다 스릴 없다',
#  '우리나라 정서 하고 안 맞다',
#  '어디 선 많이 보다 흔하다 스토리',
#  '최고 드라마',
#  '우리 모두 누군가 에게 섬머 이다',
#  '힘알 하나 없다 주인공 맥 다 빠지다',
#  '너무 너무 귀엽다 영화',
#  '전형 적 인 일본 식 엽기 괴짜 코 메다 그 특이하다 끌리다 왜 지',
#  '오다 걸 점 이상 준 사람 뭐 지 나루토 극장판 중 가장 쓰래 기',
#  '정당하다 노력 이란 보상 받다 마련 이다 나름 일정 성취 있다 좋다 결실 거두다 작품',
#  '아씨 울다',
#  '기적 이미 일어나다',
#  '아이 함께 보기 좋다 그냥 그렇다',
#  '전율 느끼다',
#  '여기저기 지저분하다 내용 기적 인 사람 역겹다 연 애사 마지막 갈수록 시청률 안 나오다 막 갈겨쓰다',
#  '별로 완전 별로 마지막 빼다 넘다 유치하다 재미없다',
#  '세월 지나다 다시 보다 뭔가 먹다 먹다 함 다르다 공감 사람 라면 가슴속 명작 남 듯',
#  '아이 보기 엔 좋다',
#  '보 니까 선정 성 세 같다 그래도 액션 좋다',
#  '카타르 시스 느끼다 충분하다 값지다 영화 이다',
#  '여주 린 제이 로 닮다 전체 적 인 분위기 나 배경 좋다 내용 지루하다',
#  '당신 솔로 아니다 영화 보지 말다',
#  '남 차안 에서 전화통화 하 는걸 분 가까이 구경 하고 있다 폰부스 명작 이라 생각 영화 진짜 장난 하나',
#  '전형 적 인 저 질 영화',
#  '답 알다',
#  '재미 잇다 매우',
#  '진짜 자다 만들다 수작',
#  '제발 찍다 현기증 나다 말 이에요',
#  '너무나도 따뜻하다 마음 따뜻하다 한번 쯤 자신 되돌아보다 만들다 영화',
#  '뭔가 조금씩 부족하다 영화 놀래다 킬 려면 확 놀래다 키 던지다 어정쩡하다',
#  '거 차다 소재 차다 좋다 내용 전개 개판 사람 수도 많다 총 있다 그걸 지다 들다 끼리 서로 다 흩어지다 일방 적 밀리 네 거기 다 식인종 이라 면서 표현 좀비 로 어쩌잔거 야 식인 인하다 인성 말살 되다 짐승 화 되어다 표현 이라도 있다',
#  '포스터 만 그렇다 싸하다 구역 이라는 이름 만 가다 쓸다 영화 완전 졸작 이다 액션 신도 개 허다 술 하고 스토리 이상하다',
#  '대체 왜 재미없다 거지 난 존나 재밌다',
#  '늑대 여정 너무 낭만 적 이다 애니 스토리 좋다 음악 일본 애니 중 탑 뛰어나다',
#  '미국 흑인 민권 운동 사르다 완벽하다 요약',
#  '그 뛰어내리다 않다 어떻다 되어다',
#  '점 대 나오다 그냥 단순하다 액션 공포물 아니다 긴장감 공포 감 연출 쩔다 음악 좋다 몇 년 지나다 기억나다 인상 적 인 좀비 물 인데 평점 너무 짜다 줌',
#  '아역 연기 좋다 내용 쓰레기',
#  '진짜 재미없다 극장 에서 보다 없다 스릴러 라 길 래 보다 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ 웃음 밖에 안 나오다 혹시 나 절대 보다 진짜 제발',
#  '평점 믿다 셈 재밌다',
#  '거 좋다 놈 뭐 것 이야 ㅡ ㅡ',
#  '게 영화 냐 년도 영화 냐 쓰래 기 아',
#  '믿다',
#  '너무 구식 웃기다 함 보다 내내 지겹다 움',
#  '이렇다 좋아하다 사람 정신 세계 궁금하다',
#  '연예계 현실 알리다 마음 알다 영화 재미 없다 지루하다 죽 뻔',
#  '아주 재미있다 책 보다 정말 재미있다',
#  '끝내주다 재밌다',
#  '유투브 동영상 돈 내다 보다 낫다 생각 들다 영화',
#  '아쉽다 점도 있다 스토리 맞다 분위기 나 배경 지하철 기관사 삶 등 자다 묘사',
#  '스타워즈 편 맞다 떨어지다 자다 만들다 영화 최고 에피소드 다스베이더 탄생 루크 레이어 운명 알다 레전드',
#  '소희 귀엽다 귀엽다 졸귀',
#  '소문나다 잔치 호화 캐스팅 먹다 건 없다',
#  '주성치 영화 최고 졸작',
#  '구 우우 웃',
#  '딱하다 흠잡다 것 두근거리다 것 없다 교과서 적 플레이',
#  '영화 중심 역시 스토리 인 것 반전 반전 너무 재미있다',
#  '아니다 아니다',
#  '차다 재미있다 연기 발 로 삼류 배우 얼굴 보다 ㅋㅋㅋ',
#  '재밌다',
#  '것 재밌다',
#  '점도 아깝다 평 쓰다 것 귀찮다 보다 내내 오글거리다 손발 사라지다 줄 알다',
#  '기대 안 하고 보다 영화 보다 내내 몰입 재미있다 보다',
#  '유쾌하다 스릴러 적 인 요소 자다 어울리다 명작 후속작 보다 훨씬 매력 있다 두다 두다 간직 두 면서 꺼내다 보고 싶다 영화',
#  '좋다 괜찮다',
#  '명작 너무 좋다 드라마 스토리 캐스팅 연기 음악 연출 모두 완벽하다',
#  '괜찮다 영화 영화 괜찮다 나영 언니 완전 머싯 고 예쁘다',
#  '일단 재미있다 고래 몇 마리 로 국가 적 호들갑 뜨다 오버 스럽다 그렇다 모습 우리 모두 가다 살다 지구 생명 이란 메세지 참으로 감동 적 이다',
#  '지금 첨 보다 회 만 보다 볼 끄다 보다 주말 밤새 완주 여운 많이 남다 드라마',
#  '애니메이션 뮬란 아쉽다 전쟁씬 그렇다 연기 그렇다 이야기 그렇다 그저 그렇다',
#  '기대 않다 봣는데 진짜 내용 좋다 재미 있다',
#  '좋다',
#  '슬프다 맑음 파문 주목 하 라',
#  '김윤진 좋아하다',
#  '재밌다 따다',
#  '무리수 되어다 버리다 코미디 기획 상품',
#  '나 홀로 집 오다 더불다 나 최고 영화',
#  '나 떠오르다 그 옛날 국산 애니 아마겟돈 악몽',
#  '완전 역겹다 쓰레기 영화 다 기술 적 수준 떠나다 각본 무 개념',
#  '고결하다 신사 께서 무슨 짓 하셧을까',
#  '캬 개다 ㅎㅎㅎㅎ',
#  '보다 너무 너무 재미있다',
#  '김소현 팬 되다 너무 재밌다',
#  '삐 에로 오다 흑인 남자 싸우다 때 재미있다 ㅋㅋㅋ 아웃 겨',
#  '유럽 영화 이번 정부 많이 들어오다 즐겁다 그 내용 왜 이리 진부하다 걸다 유럽 영화 욕 되게 소리 다',
#  '왠만하다 허다 접영 화 재미있다 보다 이건 도르다 넘어서다',
#  '어떻다 누구 다른 이의 삶 죽음 대해 왈가 왈부 순 없다',
#  '굿굿굿 또 또해 라 제발',
#  '주님 께서 부르다 제 여기 있다',
#  '미성년 돈 많다 아저씨 에게 순결 바치 고 데인 후 결국 정신차리다 공부 명문 대가 진부하다 결말',
#  '정말 재밌다 보다 빈센트 꼬마 연기 너무 ㅎ',
#  '솔직하다 원작 보다 훨씬 낫다 원작 무슨 인간 말 못 설정',
#  '말 필요없다 아 진심 개 재밌다',
#  '보 니까 양반 다세포 소녀 감독 이네',
#  '굿 잡 친구 랑 또 보고 싶다',
#  '재미 진짜 흥 근데 새끼 관 종인 ㅋㅋㅋ',
#  '야경 꾼 보다 엉망 지루함',
#  '예원 찡 그만 울 어',
#  '근 년 동안 보다 모든 영화 통틀어 서 최악 영화 시간 남아돌다 때 보다 시간 아깝다 역대 급 쓰레기 영화',
#  '감동 이다 참고 로 영화 보신 분들 마지막 엔딩 부분 자막 으로나 오는 부분 잇다 게 영화상 에서 실화 라는 거지 진짜 레알 현재 실제 로 실화 라는 말다 전지현 피디 자다 다큐 찍다 그 다큐 에서 엔딩 장면 이지 진짜 실제 아니다 에여 쨋 든',
#  '달기지 미니어쳐 티 팍팍 나다 우뢔매 보다 알다 혹시 특수 효과 감독 심형래',
#  '재미 드럽다 없다 ㅋㅋㅋ',
#  '야 세르게이 작다 고추 맵다 맛 보여주다',
#  '정여립 정철 기축옥사 까지 스토리 탄탄하다 좋다 배우 연기 차다 남녀 주인공 케미 좋다 챙기다 볼 수 밖에 없다 드라마 ㅠㅠㅠㅠ',
#  '개 영화 네 요 내 용도 없다 그냥 심심하다 만들다 영화',
#  '두 개 줄다 알바 많다 아 후 보다 없다 채널 돌리다 다시 다른 데 로 돌리다 들다',
#  '왜 점 줄 수 없다',
#  '영화사 남 작품 실험영화 완성 보다',
#  '자식 그렇게 때리다',
#  '게 대체 무슨 내용 이야',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 옛 다 점 이나 처먹어랔 ㅋㅋㅋㅋㅋㅋㅋㅋ 게 점 급 이건 점 짜다 내용 결말 살다 살다 뭐 이딴',
#  '감동 적다 좋다',
#  '초반 개 재미없다 보다 점점 재밌다 짐 외계인 내 알다 에일리언 나오다 외계인 아니다',
#  '쇼핑 백 잊혀지다 않다',
#  '의도 좋다 너무 몰입 안되다 어떡하다',
#  '유치하다 가볍다 볼 만 함',
#  '화려하다 색채 때문 눈 아프다 그 나름 대로 화려 연예계 여자 욕망 대해 표현 해내다 같다 보다 진짜 리리 코 심정 가지다 연 옌 있다 같다 나르다 한번 보다 알다 사람 날 어떻다 사랑 하 냐 그렇다 대사 나오다 때 소름 돋다 연예인 많다 사랑받다 차다 허전하다',
#  '보다 수 지나다 아직도 생생하다 고양이 귀신 복수 진짜 무섭다',
#  '영상 대학교 졸업 작품 같다 그렇다 꽤 나 많다 담다 영화 임 에는 분명하다',
#  '최강 전차 부대',
#  'ㅇㅇ',
#  '진짜 어이없다 소재 라고 생각 보다 개 웃기다 남자 로서 솔직하다 조금 부르다 있다',
#  '전 기세 아깝다',
#  '초등학교 때 선생님 보여주다 영화 시간 흐르다 기억나다 에이즈 걸리다 남다 운동화 이다 그때 보다 영화 뭐 이다 궁금하다 그 영화 바로 굿바이 마이 프렌드 이다 년 전 이나 년후 나 명작 시간 흐르다 명작 이다',
#  '넘다 재밌다 ㅅ ㅎㅎㅎ',
#  '설리 년생 인데 년도 영화 어떻다 나오다',
#  '샷 연결 아니다 충돌 만큼이나 거룩하다 제목 또한 인상 적 구려',
#  'ㅋㅋㅋ 재미없다',
#  '오오 난 여태 까지 맷 데이먼 최고 영화 보다 얼티 메이 텀 라이언 일 병구 뿐이다 알다 ㅠ 굿윌헌팅도쩐당',
#  '이야기 자체 흥미 끌 지 못',
#  '날 로그인 만들다 청춘 이여 영원하다',
#  '현정 언니 짱 죠 완전 잼 잇다 ㅎ',
#  '영 상미 예쁘다 좋다 러닝 타임 시간 넘다 초반 분 줄거리 다 나가다 엄청 지루하다 화보 집 보다 기분 일본 영화 특유 그 이해 못 희한하다 있다',
#  '스토리 연결 전혀 안되다 편집 끼우다 맞추다 드라마 말아먹다 작품',
#  '여자 주인공 예쁘다 끝 까지 보다',
#  '지구 지키다 혹 작품 보고 만들다 건 아니다',
#  '저렇게 힘들다 영화 만들다 왜 한국영 화 다 쓰레기 냐',
#  '케릭 터 살다 미장센 훌륭하다 이야기 몰입도 있다 불필요하다 샷 존재 않다 노인 위 한나 라는 없다 먼저 보다 코 엔 감독 매력 적 인 영화 만들다 멋있다 사람',
#  '마지막 황당하다 좋다 영화',
#  '우연히 돌리다 가다 사로잡히다 최근 년 간 보다 코미디 영화 중 최고',
#  '연 기 굿 화이팅 누나',
#  '마이클 베이 최근 작 볼때 마다 느끼다 블록버스터 액션 장르 라도 탄탄하다 시나리오 영화 필수 라는 것 그리고 당신 기대하다 메간폭스 늙다',
#  '점 없다 점 너무 후',
#  '미달 연예계 바라보다 태도 고치다',
#  '파괴 되다 관객',
#  '알콜중독자 덕 평점 낮다',
#  '중견 배우 만들다 긴장감 나름 긴장감 있다 싸우다 보다 술사 의하다 헛 웃음 나오다',
#  '남자 주인공 늑대 인간 변하다 끝나다 유 평점 보고 안 보다 보다 재밌다 유 보다 이렇다 실물 특수 효과 더 보다 재미 있다 어유 웃기다 유 근 디 제목 번역 어느 바보 거여 그냥 늑대 인간 아니다',
#  '정말 최고 명작 성인 되다 보다 이집트 왕자 또 다른 감동 그 자체 네 요',
#  '이영화 만 성공 스퀘어 닉스 랑 합병 일 없다',
#  '울컥 사회 현실',
#  '기대 하나 도안 하 면 일 없다 때 보기 좋다 영화',
#  '소림사 관문 통과 진짜 어렵다 보여주다 영화 극장 에서 개봉 반갑다',
#  '시리즈 안 나오다 ㅠㅠㅠㅠㅠㅠㅠㅠ',
#  '끝나다 사실 너무 슬프다 가슴 뻥 뚫리다 버리다 같다',
#  ...]

# %% [markdown]
# ### 4. Feature Engineering + Model Training / Evaluation

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

# %%
cvect = CountVectorizer()
lr = LogisticRegression(random_state=2022)
pipeline = Pipeline([('CVECT', cvect), ('LR', lr)])
# %time pipeline.fit(X_train, y_train)
# Out:
# CPU times: total: 14 s
# Wall time: 2.94 s
# Pipeline(steps=[('CVECT', CountVectorizer()),
#                 ('LR', LogisticRegression(random_state=2022))])

# %%
pipeline.score(X_test, y_test)
# Out:
# 0.8272742159993449

# %% [markdown]
# ### 5. Test

# %%
review1 = '모든 국민이 봤으면 하는 영화입니다.'
review2 = '생각보다 지루하고 별로였네요... 보면서 좀 졸았습니다.'

# %%
# 전처리
import re
review1 = re.sub('[^가-힣]',' ', review1)
review2 = re.sub('[^가-힣]',' ', review2)

# %%
morphs = okt.morphs(review1, stem=True)
review1 = ' '.join([word for word in morphs if word not in stopwords])
morphs = okt.morphs(review2, stem=True)
review2 = ' '.join([word for word in morphs if word not in stopwords])

# %%
pipeline.predict([review1, review2])
# Out:
# array([1, 0], dtype=int64)

# %% [markdown]
# ### 6. Parameter Search

# %%
from sklearn.model_selection import GridSearchCV
params = {
    'CVECT__ngram_range': [(1,1),(1,2)],
    'CVECT__max_df': [0.95, 0.98],
    'LR__C': [1, 5]
}

# %%
grid_pipe = GridSearchCV(pipeline, params, scoring='accuracy', cv=3, n_jobs=-1)
# %time grid_pipe.fit(X_train, y_train)
# Out:
# CPU times: total: 55.1 s
# Wall time: 56.4 s
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('CVECT', CountVectorizer()),
#                                        ('LR',
#                                         LogisticRegression(random_state=2022))]),
#              n_jobs=-1,
#              param_grid={'CVECT__max_df': [0.95, 0.98],
#                          'CVECT__ngram_range': [(1, 1), (1, 2)],
#                          'LR__C': [1, 5]},
#              scoring='accuracy')

# %%
grid_pipe.best_params_
# Out:
# {'CVECT__max_df': 0.95, 'CVECT__ngram_range': (1, 2), 'LR__C': 1}

# %%
grid_pipe.best_estimator_.score(X_test, y_test)
# Out:
# 0.8480307868664538
